# %% [markdown]
# # Edge Addition Algorithm - simple implementation example

# %% [markdown]
# <font size="3">Run time is around ~5 minutes with the default input. \
# \
# In this example we will use the E.A.A. model to build a low-connectivity DCA model. \
# The information that we have about the training RNA family consists in: the sequence alignment and the consenus secondary structure (both trough the Covariance Model) and the 3D contacts trough the PDB file. </font>

# %%
include("../src/FCSeqTools.jl");

# %% [markdown]
# <font size="3">Here is an example of  RF00379 molecule and its associated consensus secondary structure. \
# To make the execution faster we will not generate full lenght molecules but just a portion from nucleotide 55 to 102. </font>

# %%
natural_sequences = do_number_matrix_prot(do_letter_matrix("../data/CM_130530_MC.fasta"), 0.2);

# %% [markdown]
# <font size="3">Here is a segment example with its associated secondary structure. \
# The database has a different size because the data-cleaning procedure depends on the region selected. \
# Now we will run the E.A.A. building up our ineraction netwotk edge by edge till we reach a good performance generative model. \
# At each iteration the algorithm reports: the added edge, the iteration number, the number of total added edges and the connectivity percentace of the fully connected case.\
# Each 15 iterations the algorithm reports: the model score (Pearson between natural and artificial two-point correlations), the model mean energy, the model partition function and the model entropy.

# %%
using Random

n_step = 100_000
method = "cumulative"
fraction = 0.3
stop = 0.9
pseudo_count = 0.5
s = time()
Random.seed!(4) 
notebook = "3"
#                                                                                                 #21                 #12000                                           
score, likelihood_gain, generated_sequences, Jij, h, contact_list, site_degree, edge_list, path = E_A_A(21, n_step, pseudo_count, 12000, natural_sequences,"example_output.txt", method, notebook, fraction, stop); 
s = time() - s
# Out:
# Fully connected model has 4560 edges, 2010960 elements and a score around ~ 0.95
#
# iteration = 20,   Score = 0.093
#
#  <E> = 195.86,  log(Z) = -0.43,   S = 195.43
#  edges: 20,   elements: 78,   edge complexity: 0.44 %,  elements complexity: 0.0 %
#
# iteration = 40,   Score = 0.172
#
#  <E> = 193.52,  log(Z) = -0.82,   S = 192.7
#  edges: 40,   elements: 172,   edge complexity: 0.88 %,  elements complexity: 0.01 %
#
# iteration = 60,   Score = 0.22
#
#  <E> = 190.83,  log(Z) = -0.94,   S = 189.88
#  edges: 60,   elements: 293,   edge complexity: 1.32 %,  elements complexity: 0.01 %
#
# iteration = 80,   Score = 0.254
#
#  <E> = 188.96,  log(Z) = -1.24,   S = 187.72
#  edges: 78,   elements: 410,   edge complexity: 1.71 %,  elements complexity: 0.02 %
#
# iteration = 100,   Score = 0.305
#
#  <E> = 187.07,  log(Z) = -1.52,   S = 185.55
#  edges: 96,   elements: 519,   edge complexity: 2.11 %,  elements complexity: 0.03 %
#
# iteration = 120,   Score = 0.344
#
#  <E> = 184.75,  log(Z) = -1.59,   S = 183.16
#  edges: 116,   elements: 645,   edge complexity: 2.54 %,  elements complexity: 0.03 %
#
# iteration = 140,   Score = 0.375
#
#  <E> = 183.44,  log(Z) = -1.75,   S = 181.69
#  edges: 136,   elements: 753,   edge complexity: 2.98 %,  elements complexity: 0.04 %
#
# iteration = 160,   Score = 0.415
#
#  <E> = 180.91,  log(Z) = -1.63,   S = 179.28
#  edges: 153,   elements: 862,   edge complexity: 3.36 %,  elements complexity: 0.04 %
#
# iteration = 180,   Score = 0.444
#
#  <E> = 179.57,  log(Z) = -1.7,   S = 177.87
#  edges: 171,   elements: 984,   edge complexity: 3.75 %,  elements complexity: 0.05 %
#
# iteration = 200,   Score = 0.478
#
#  <E> = 177.07,  log(Z) = -1.76,   S = 175.31
#  edges: 190,   elements: 1106,   edge complexity: 4.17 %,  elements complexity: 0.05 %
#
# iteration = 220,   Score = 0.503
#
#  <E> = 174.87,  log(Z) = -1.78,   S = 173.09
#  edges: 207,   elements: 1234,   edge complexity: 4.54 %,  elements complexity: 0.06 %
#
# iteration = 240,   Score = 0.524
#
#  <E> = 174.46,  log(Z) = -2.03,   S = 172.43
#  edges: 226,   elements: 1377,   edge complexity: 4.96 %,  elements complexity: 0.07 %
#
# iteration = 260,   Score = 0.55
#
#  <E> = 172.89,  log(Z) = -2.07,   S = 170.83
#  edges: 245,   elements: 1527,   edge complexity: 5.37 %,  elements complexity: 0.08 %
#
# iteration = 280,   Score = 0.57
#
#  <E> = 171.68,  log(Z) = -2.06,   S = 169.63
#  edges: 264,   elements: 1657,   edge complexity: 5.79 %,  elements complexity: 0.08 %
#
# iteration = 300,   Score = 0.583
#
#  <E> = 169.71,  log(Z) = -2.07,   S = 167.64
#  edges: 282,   elements: 1808,   edge complexity: 6.18 %,  elements complexity: 0.09 %
#
# iteration = 320,   Score = 0.598
#
#  <E> = 168.2,  log(Z) = -2.19,   S = 166.01
#  edges: 298,   elements: 1968,   edge complexity: 6.54 %,  elements complexity: 0.1 %
#
# iteration = 340,   Score = 0.618
#
#  <E> = 166.21,  log(Z) = -2.15,   S = 164.06
#  edges: 317,   elements: 2120,   edge complexity: 6.95 %,  elements complexity: 0.11 %
#
# iteration = 360,   Score = 0.636
#
#  <E> = 165.87,  log(Z) = -2.11,   S = 163.76
#  edges: 336,   elements: 2268,   edge complexity: 7.37 %,  elements complexity: 0.11 %
#
# iteration = 380,   Score = 0.646
#
#  <E> = 164.0,  log(Z) = -2.08,   S = 161.92
#  edges: 353,   elements: 2440,   edge complexity: 7.74 %,  elements complexity: 0.12 %
#
# iteration = 400,   Score = 0.658
#
#  <E> = 161.9,  log(Z) = -2.06,   S = 159.84
#  edges: 370,   elements: 2601,   edge complexity: 8.11 %,  elements complexity: 0.13 %
#
# iteration = 420,   Score = 0.666
#
#  <E> = 160.98,  log(Z) = -2.11,   S = 158.87
#  edges: 386,   elements: 2775,   edge complexity: 8.46 %,  elements complexity: 0.14 %
#
# iteration = 440,   Score = 0.682
#
#  <E> = 159.01,  log(Z) = -1.98,   S = 157.04
#  edges: 402,   elements: 2935,   edge complexity: 8.82 %,  elements complexity: 0.15 %
#
# iteration = 460,   Score = 0.694
#
#  <E> = 158.03,  log(Z) = -1.97,   S = 156.06
#  edges: 421,   elements: 3133,   edge complexity: 9.23 %,  elements complexity: 0.16 %
#
# iteration = 480,   Score = 0.7
#
#  <E> = 156.31,  log(Z) = -1.84,   S = 154.48
#  edges: 439,   elements: 3312,   edge complexity: 9.63 %,  elements complexity: 0.16 %
#
# iteration = 500,   Score = 0.711
#
#  <E> = 155.26,  log(Z) = -1.94,   S = 153.32
#  edges: 454,   elements: 3488,   edge complexity: 9.96 %,  elements complexity: 0.17 %
#
# iteration = 520,   Score = 0.718
#
#  <E> = 153.76,  log(Z) = -1.9,   S = 151.85
#  edges: 470,   elements: 3680,   edge complexity: 10.31 %,  elements complexity: 0.18 %
#
# iteration = 540,   Score = 0.725
#
#  <E> = 152.53,  log(Z) = -1.75,   S = 150.78
#  edges: 486,   elements: 3867,   edge complexity: 10.66 %,  elements complexity: 0.19 %
#
# iteration = 560,   Score = 0.737
#
#  <E> = 151.53,  log(Z) = -1.73,   S = 149.8
#  edges: 503,   elements: 4030,   edge complexity: 11.03 %,  elements complexity: 0.2 %
#
# iteration = 580,   Score = 0.74
#
#  <E> = 149.94,  log(Z) = -1.75,   S = 148.19
#  edges: 518,   elements: 4228,   edge complexity: 11.36 %,  elements complexity: 0.21 %
#
# iteration = 600,   Score = 0.748
#
#  <E> = 149.28,  log(Z) = -1.7,   S = 147.58
#  edges: 534,   elements: 4423,   edge complexity: 11.71 %,  elements complexity: 0.22 %
#
# iteration = 620,   Score = 0.757
#
#  <E> = 147.82,  log(Z) = -1.57,   S = 146.25
#  edges: 550,   elements: 4651,   edge complexity: 12.06 %,  elements complexity: 0.23 %
#
# iteration = 640,   Score = 0.761
#
#  <E> = 146.8,  log(Z) = -1.47,   S = 145.33
#  edges: 564,   elements: 4834,   edge complexity: 12.37 %,  elements complexity: 0.24 %
#
# iteration = 660,   Score = 0.769
#
#  <E> = 146.48,  log(Z) = -1.45,   S = 145.02
#  edges: 581,   elements: 5036,   edge complexity: 12.74 %,  elements complexity: 0.25 %
#
# iteration = 680,   Score = 0.774
#
#  <E> = 145.38,  log(Z) = -1.34,   S = 144.04
#  edges: 596,   elements: 5237,   edge complexity: 13.07 %,  elements complexity: 0.26 %
#
# iteration = 700,   Score = 0.779
#
#  <E> = 143.38,  log(Z) = -1.21,   S = 142.17
#  edges: 613,   elements: 5452,   edge complexity: 13.44 %,  elements complexity: 0.27 %
#
# iteration = 720,   Score = 0.784
#
#  <E> = 142.95,  log(Z) = -1.08,   S = 141.87
#  edges: 627,   elements: 5665,   edge complexity: 13.75 %,  elements complexity: 0.28 %
#
# iteration = 740,   Score = 0.788
#
#  <E> = 141.83,  log(Z) = -0.84,   S = 140.99
#  edges: 645,   elements: 5858,   edge complexity: 14.14 %,  elements complexity: 0.29 %
#
# iteration = 760,   Score = 0.789
#
#  <E> = 140.88,  log(Z) = -0.79,   S = 140.09
#  edges: 662,   elements: 6084,   edge complexity: 14.52 %,  elements complexity: 0.3 %
#
# iteration = 780,   Score = 0.793
#
#  <E> = 139.52,  log(Z) = -0.57,   S = 138.95
#  edges: 676,   elements: 6275,   edge complexity: 14.82 %,  elements complexity: 0.31 %
#
# iteration = 800,   Score = 0.797
#
#  <E> = 139.16,  log(Z) = -0.55,   S = 138.62
#  edges: 691,   elements: 6468,   edge complexity: 15.15 %,  elements complexity: 0.32 %
#
# iteration = 820,   Score = 0.803
#
#  <E> = 138.23,  log(Z) = -0.52,   S = 137.71
#  edges: 706,   elements: 6668,   edge complexity: 15.48 %,  elements complexity: 0.33 %
#
# iteration = 840,   Score = 0.805
#
#  <E> = 137.66,  log(Z) = -0.29,   S = 137.36
#  edges: 719,   elements: 6880,   edge complexity: 15.77 %,  elements complexity: 0.34 %
#
# iteration = 860,   Score = 0.807
#
#  <E> = 137.07,  log(Z) = -0.22,   S = 136.85
#  edges: 737,   elements: 7106,   edge complexity: 16.16 %,  elements complexity: 0.35 %
#
# iteration = 880,   Score = 0.812
#
#  <E> = 135.55,  log(Z) = -0.12,   S = 135.42
#  edges: 749,   elements: 7310,   edge complexity: 16.43 %,  elements complexity: 0.36 %
#
# iteration = 900,   Score = 0.815
#
#  <E> = 134.88,  log(Z) = -0.01,   S = 134.86
#  edges: 766,   elements: 7545,   edge complexity: 16.8 %,  elements complexity: 0.38 %
#
# iteration = 920,   Score = 0.818
#
#  <E> = 133.97,  log(Z) = 0.33,   S = 134.29
#  edges: 782,   elements: 7771,   edge complexity: 17.15 %,  elements complexity: 0.39 %
#
# iteration = 940,   Score = 0.819
#
#  <E> = 133.77,  log(Z) = 0.48,   S = 134.25
#  edges: 797,   elements: 7982,   edge complexity: 17.48 %,  elements complexity: 0.4 %
#
# iteration = 960,   Score = 0.82
#
#  <E> = 132.87,  log(Z) = 0.69,   S = 133.55
#  edges: 813,   elements: 8223,   edge complexity: 17.83 %,  elements complexity: 0.41 %
#
# iteration = 980,   Score = 0.824
#
#  <E> = 131.8,  log(Z) = 0.87,   S = 132.67
#  edges: 831,   elements: 8436,   edge complexity: 18.22 %,  elements complexity: 0.42 %
#
# iteration = 1000,   Score = 0.826
#
#  <E> = 130.51,  log(Z) = 1.13,   S = 131.64
#  edges: 847,   elements: 8673,   edge complexity: 18.57 %,  elements complexity: 0.43 %
#
# iteration = 1020,   Score = 0.827
#
#  <E> = 130.39,  log(Z) = 1.27,   S = 131.66
#  edges: 859,   elements: 8910,   edge complexity: 18.84 %,  elements complexity: 0.44 %
#
# iteration = 1040,   Score = 0.829
#
#  <E> = 129.36,  log(Z) = 1.59,   S = 130.94
#  edges: 873,   elements: 9120,   edge complexity: 19.14 %,  elements complexity: 0.45 %
#
# iteration = 1060,   Score = 0.833
#
#  <E> = 128.49,  log(Z) = 1.75,   S = 130.24
#  edges: 889,   elements: 9326,   edge complexity: 19.5 %,  elements complexity: 0.46 %
#
# iteration = 1080,   Score = 0.834
#
#  <E> = 127.32,  log(Z) = 2.01,   S = 129.33
#  edges: 906,   elements: 9546,   edge complexity: 19.87 %,  elements complexity: 0.47 %
#
# iteration = 1100,   Score = 0.837
#
#  <E> = 126.78,  log(Z) = 2.17,   S = 128.95
#  edges: 924,   elements: 9766,   edge complexity: 20.26 %,  elements complexity: 0.49 %
#
# iteration = 1120,   Score = 0.839
#
#  <E> = 126.11,  log(Z) = 2.25,   S = 128.36
#  edges: 937,   elements: 10021,   edge complexity: 20.55 %,  elements complexity: 0.5 %
#
# iteration = 1140,   Score = 0.84
#
#  <E> = 125.85,  log(Z) = 2.4,   S = 128.26
#  edges: 951,   elements: 10236,   edge complexity: 20.86 %,  elements complexity: 0.51 %
#
# iteration = 1160,   Score = 0.842
#
#  <E> = 124.75,  log(Z) = 2.64,   S = 127.4
#  edges: 969,   elements: 10431,   edge complexity: 21.25 %,  elements complexity: 0.52 %
#
# iteration = 1180,   Score = 0.844
#
#  <E> = 124.76,  log(Z) = 2.84,   S = 127.6
#  edges: 982,   elements: 10652,   edge complexity: 21.54 %,  elements complexity: 0.53 %
#
# iteration = 1200,   Score = 0.845
#
#  <E> = 123.62,  log(Z) = 3.07,   S = 126.69
#  edges: 998,   elements: 10872,   edge complexity: 21.89 %,  elements complexity: 0.54 %
#
# iteration = 1220,   Score = 0.845
#
#  <E> = 122.64,  log(Z) = 3.32,   S = 125.96
#  edges: 1014,   elements: 11133,   edge complexity: 22.24 %,  elements complexity: 0.55 %
#
# iteration = 1240,   Score = 0.849
#
#  <E> = 122.23,  log(Z) = 3.46,   S = 125.69
#  edges: 1030,   elements: 11365,   edge complexity: 22.59 %,  elements complexity: 0.57 %
#
# iteration = 1260,   Score = 0.851
#
#  <E> = 121.68,  log(Z) = 3.66,   S = 125.33
#  edges: 1043,   elements: 11593,   edge complexity: 22.87 %,  elements complexity: 0.58 %
#
# iteration = 1280,   Score = 0.854
#
#  <E> = 121.05,  log(Z) = 3.89,   S = 124.94
#  edges: 1060,   elements: 11824,   edge complexity: 23.25 %,  elements complexity: 0.59 %
#
# iteration = 1300,   Score = 0.855
#
#  <E> = 120.0,  log(Z) = 4.21,   S = 124.21
#  edges: 1073,   elements: 12049,   edge complexity: 23.53 %,  elements complexity: 0.6 %
#
# iteration = 1320,   Score = 0.856
#
#  <E> = 119.89,  log(Z) = 4.48,   S = 124.37
#  edges: 1086,   elements: 12298,   edge complexity: 23.82 %,  elements complexity: 0.61 %
#
# iteration = 1340,   Score = 0.856
#
#  <E> = 118.63,  log(Z) = 4.79,   S = 123.42
#  edges: 1091,   elements: 12543,   edge complexity: 23.93 %,  elements complexity: 0.62 %
#
# iteration = 1360,   Score = 0.859
#
#  <E> = 118.12,  log(Z) = 4.95,   S = 123.07
#  edges: 1106,   elements: 12767,   edge complexity: 24.25 %,  elements complexity: 0.63 %
#
# iteration = 1380,   Score = 0.859
#
#  <E> = 117.51,  log(Z) = 5.18,   S = 122.68
#  edges: 1118,   elements: 12987,   edge complexity: 24.52 %,  elements complexity: 0.65 %
#
# iteration = 1400,   Score = 0.859
#
#  <E> = 116.9,  log(Z) = 5.4,   S = 122.3
#  edges: 1133,   elements: 13215,   edge complexity: 24.85 %,  elements complexity: 0.66 %
#
# iteration = 1420,   Score = 0.861
#
#  <E> = 116.35,  log(Z) = 5.54,   S = 121.88
#  edges: 1144,   elements: 13451,   edge complexity: 25.09 %,  elements complexity: 0.67 %
#
# iteration = 1440,   Score = 0.861
#
#  <E> = 116.0,  log(Z) = 5.76,   S = 121.75
#  edges: 1158,   elements: 13689,   edge complexity: 25.39 %,  elements complexity: 0.68 %
#
# iteration = 1460,   Score = 0.864
#
#  <E> = 115.02,  log(Z) = 5.93,   S = 120.95
#  edges: 1170,   elements: 13933,   edge complexity: 25.66 %,  elements complexity: 0.69 %
#
# iteration = 1480,   Score = 0.865
#
#  <E> = 114.68,  log(Z) = 6.09,   S = 120.77
#  edges: 1185,   elements: 14183,   edge complexity: 25.99 %,  elements complexity: 0.71 %
#
# iteration = 1500,   Score = 0.867
#
#  <E> = 114.1,  log(Z) = 6.37,   S = 120.47
#  edges: 1201,   elements: 14400,   edge complexity: 26.34 %,  elements complexity: 0.72 %
#
# iteration = 1520,   Score = 0.868
#
#  <E> = 113.35,  log(Z) = 6.64,   S = 119.98
#  edges: 1215,   elements: 14655,   edge complexity: 26.64 %,  elements complexity: 0.73 %
#
# iteration = 1540,   Score = 0.87
#
#  <E> = 112.41,  log(Z) = 6.9,   S = 119.31
#  edges: 1229,   elements: 14886,   edge complexity: 26.95 %,  elements complexity: 0.74 %
#
# iteration = 1560,   Score = 0.869
#
#  <E> = 112.27,  log(Z) = 7.1,   S = 119.37
#  edges: 1239,   elements: 15117,   edge complexity: 27.17 %,  elements complexity: 0.75 %
#
# iteration = 1580,   Score = 0.872
#
#  <E> = 111.41,  log(Z) = 7.34,   S = 118.75
#  edges: 1254,   elements: 15349,   edge complexity: 27.5 %,  elements complexity: 0.76 %
#
# iteration = 1600,   Score = 0.873
#
#  <E> = 110.53,  log(Z) = 7.49,   S = 118.02
#  edges: 1260,   elements: 15584,   edge complexity: 27.63 %,  elements complexity: 0.77 %
#
# iteration = 1620,   Score = 0.874
#
#  <E> = 110.2,  log(Z) = 7.76,   S = 117.97
#  edges: 1275,   elements: 15811,   edge complexity: 27.96 %,  elements complexity: 0.79 %
#
# iteration = 1640,   Score = 0.873
#
#  <E> = 109.13,  log(Z) = 8.0,   S = 117.14
#  edges: 1290,   elements: 16083,   edge complexity: 28.29 %,  elements complexity: 0.8 %
#
# iteration = 1660,   Score = 0.875
#
#  <E> = 109.03,  log(Z) = 8.18,   S = 117.21
#  edges: 1302,   elements: 16326,   edge complexity: 28.55 %,  elements complexity: 0.81 %
#
# iteration = 1680,   Score = 0.875
#
#  <E> = 108.12,  log(Z) = 8.33,   S = 116.45
#  edges: 1315,   elements: 16563,   edge complexity: 28.84 %,  elements complexity: 0.82 %
#
# iteration = 1700,   Score = 0.877
#
#  <E> = 108.31,  log(Z) = 8.57,   S = 116.88
#  edges: 1326,   elements: 16818,   edge complexity: 29.08 %,  elements complexity: 0.84 %
#
# iteration = 1720,   Score = 0.877
#
#  <E> = 107.33,  log(Z) = 8.8,   S = 116.12
#  edges: 1344,   elements: 17050,   edge complexity: 29.47 %,  elements complexity: 0.85 %
#
# iteration = 1740,   Score = 0.879
#
#  <E> = 106.6,  log(Z) = 9.09,   S = 115.69
#  edges: 1356,   elements: 17275,   edge complexity: 29.74 %,  elements complexity: 0.86 %
#
# iteration = 1760,   Score = 0.88
#
#  <E> = 105.62,  log(Z) = 9.35,   S = 114.97
#  edges: 1371,   elements: 17521,   edge complexity: 30.07 %,  elements complexity: 0.87 %
#
# iteration = 1780,   Score = 0.882
#
#  <E> = 105.53,  log(Z) = 9.56,   S = 115.08
#  edges: 1384,   elements: 17760,   edge complexity: 30.35 %,  elements complexity: 0.88 %
#
# iteration = 1800,   Score = 0.883
#
#  <E> = 104.5,  log(Z) = 9.82,   S = 114.32
#  edges: 1399,   elements: 17989,   edge complexity: 30.68 %,  elements complexity: 0.89 %
#
# iteration = 1820,   Score = 0.884
#
#  <E> = 104.02,  log(Z) = 9.87,   S = 113.9
#  edges: 1410,   elements: 18243,   edge complexity: 30.92 %,  elements complexity: 0.91 %
#
# iteration = 1840,   Score = 0.885
#
#  <E> = 104.09,  log(Z) = 10.1,   S = 114.19
#  edges: 1426,   elements: 18473,   edge complexity: 31.27 %,  elements complexity: 0.92 %
#
# iteration = 1860,   Score = 0.886
#
#  <E> = 103.24,  log(Z) = 10.27,   S = 113.5
#  edges: 1438,   elements: 18730,   edge complexity: 31.54 %,  elements complexity: 0.93 %
#
# iteration = 1880,   Score = 0.885
#
#  <E> = 103.31,  log(Z) = 10.54,   S = 113.85
#  edges: 1452,   elements: 18966,   edge complexity: 31.84 %,  elements complexity: 0.94 %
#
# iteration = 1900,   Score = 0.886
#
#  <E> = 102.2,  log(Z) = 10.82,   S = 113.02
#  edges: 1466,   elements: 19194,   edge complexity: 32.15 %,  elements complexity: 0.95 %
#
# iteration = 1920,   Score = 0.886
#
#  <E> = 101.74,  log(Z) = 11.0,   S = 112.74
#  edges: 1481,   elements: 19442,   edge complexity: 32.48 %,  elements complexity: 0.97 %
#
# iteration = 1940,   Score = 0.888
#
#  <E> = 100.83,  log(Z) = 11.28,   S = 112.11
#  edges: 1492,   elements: 19696,   edge complexity: 32.72 %,  elements complexity: 0.98 %
#
# iteration = 1960,   Score = 0.891
#
#  <E> = 100.55,  log(Z) = 11.53,   S = 112.08
#  edges: 1507,   elements: 19926,   edge complexity: 33.05 %,  elements complexity: 0.99 %
#
# iteration = 1980,   Score = 0.892
#
#  <E> = 100.1,  log(Z) = 11.78,   S = 111.89
#  edges: 1516,   elements: 20164,   edge complexity: 33.25 %,  elements complexity: 1.0 %
#
# iteration = 2000,   Score = 0.892
#
#  <E> = 99.83,  log(Z) = 12.0,   S = 111.82
#  edges: 1528,   elements: 20397,   edge complexity: 33.51 %,  elements complexity: 1.01 %
#
# iteration = 2020,   Score = 0.892
#
#  <E> = 98.74,  log(Z) = 12.31,   S = 111.05
#  edges: 1543,   elements: 20611,   edge complexity: 33.84 %,  elements complexity: 1.02 %
#
# iteration = 2040,   Score = 0.893
#
#  <E> = 98.31,  log(Z) = 12.49,   S = 110.8
#  edges: 1556,   elements: 20874,   edge complexity: 34.12 %,  elements complexity: 1.04 %
#
# iteration = 2060,   Score = 0.893
#
#  <E> = 98.08,  log(Z) = 12.77,   S = 110.84
#  edges: 1563,   elements: 21117,   edge complexity: 34.28 %,  elements complexity: 1.05 %
#
# iteration = 2080,   Score = 0.894
#
#  <E> = 98.44,  log(Z) = 13.07,   S = 111.51
#  edges: 1576,   elements: 21356,   edge complexity: 34.56 %,  elements complexity: 1.06 %
#
# iteration = 2100,   Score = 0.895
#
#  <E> = 97.38,  log(Z) = 13.32,   S = 110.7
#  edges: 1589,   elements: 21612,   edge complexity: 34.85 %,  elements complexity: 1.07 %
#
# iteration = 2120,   Score = 0.896
#
#  <E> = 96.85,  log(Z) = 13.62,   S = 110.46
#  edges: 1600,   elements: 21864,   edge complexity: 35.09 %,  elements complexity: 1.09 %
#
# iteration = 2140,   Score = 0.896
#
#  <E> = 96.16,  log(Z) = 13.89,   S = 110.06
#  edges: 1613,   elements: 22128,   edge complexity: 35.37 %,  elements complexity: 1.1 %
#
# iteration = 2160,   Score = 0.897
#
#  <E> = 95.27,  log(Z) = 14.17,   S = 109.44
#  edges: 1623,   elements: 22394,   edge complexity: 35.59 %,  elements complexity: 1.11 %
#
# iteration = 2180,   Score = 0.898
#
#  <E> = 94.87,  log(Z) = 14.4,   S = 109.27
#  edges: 1635,   elements: 22654,   edge complexity: 35.86 %,  elements complexity: 1.13 %
#
# iteration = 2200,   Score = 0.898
#
#  <E> = 94.44,  log(Z) = 14.67,   S = 109.11
#  edges: 1647,   elements: 22900,   edge complexity: 36.12 %,  elements complexity: 1.14 %
#
# iteration = 2220,   Score = 0.898
#
#  <E> = 93.88,  log(Z) = 14.86,   S = 108.74
#  edges: 1658,   elements: 23178,   edge complexity: 36.36 %,  elements complexity: 1.15 %
#
# iteration = 2240,   Score = 0.899
#
#  <E> = 92.91,  log(Z) = 15.13,   S = 108.05
#  edges: 1672,   elements: 23419,   edge complexity: 36.67 %,  elements complexity: 1.16 %
#
# iteration = 2260,   Score = 0.901
#
#  <E> = 92.98,  log(Z) = 15.35,   S = 108.33
#
# The selceted model has 1682 edges and a score = 0.9
# 97238.94945693016

# %% [markdown]
# ## saving data

# %%
using JLD

init_pseudo_count = 0.01
folder_name = "../training/" * method * string(fraction) * "_stop=" * string(stop) * "_reg="*string(pseudo_count)*"_h_ps-count=" * string(init_pseudo_count) * "nbook="*notebook

JLD.save(folder_name*"/"*"score.jld","data", score)
JLD.save(folder_name*"/"*"likelihood_gain.jld","data", likelihood_gain)
JLD.save(folder_name*"/"*"generated_sequences.jld","data", generated_sequences)
JLD.save(folder_name*"/"*"Jij.jld","data", Jij)
JLD.save(folder_name*"/"*"h.jld","data", h)
JLD.save(folder_name*"/"*"contact_list.jld","data", contact_list)
JLD.save(folder_name*"/"*"site_degree.jld","data", site_degree)
JLD.save(folder_name*"/"*"edge_list.jld","data", edge_list)

# %% [markdown]
# ## Saving the model

# %%
function print_model_to_file_prot(natural_sequences,Jij,h,filename)
    open(filename, "w") do f
        for i in 1:length(natural_sequences[1,:])
            for j in i+1:length(natural_sequences[1,:])
                for k in 1:21    
                    if k==1
                        k2=1        
                    elseif k==2
                        k2=2
                    elseif k==3
                        k2=3
                    elseif k==4
                        k2=4
                    elseif k==5
                        k2=5
                    elseif k==6
                        k2=6
                    elseif k==7
                        k2=7
                    elseif k==8
                        k2=8
                    elseif k==9
                        k2=9
                    elseif k==10
                        k2=10
                    elseif k==11
                        k2=11
                    elseif k==12
                        k2=12
                    elseif k==13
                        k2=13
                    elseif k==14
                        k2=14
                    elseif k==15
                        k2=15
                    elseif k==16
                        k2=16
                    elseif k==17
                        k2=17
                    elseif k==18
                        k2=18
                    elseif k==19
                        k2=19
                    elseif k==20
                        k2=20
                    elseif k==21
                        k2=0
                    end
                        
                    for l in 1:21
                        if l==1
                            l2=1
                        elseif l==2
                            l2=2
                        elseif l==3
                            l2=3
                        elseif l==4
                            l2=4
                        elseif l==5
                            l2=5
                        elseif l==6
                            l2=6
                        elseif l==7
                            l2=7
                        elseif l==8
                            l2=8
                        elseif l==9
                            l2=9
                        elseif l==10
                            l2=10
                        elseif l==11
                            l2=11
                        elseif l==12
                            l2=12
                        elseif l==13
                            l2=13
                        elseif l==14
                            l2=14
                        elseif l==15
                            l2=15
                        elseif l==16
                            l2=16
                        elseif l==17
                            l2=17
                        elseif l==18
                            l2=18
                        elseif l==19
                            l2=19
                        elseif l==20
                            l2=20
                        elseif l==21
                            l2=0
                        end
                        opo=Jij[i,j,21*(k-1)+l]
                        write(f,"\nJ $(i-1) $(j-1) $(k2) $(l2) $opo" )
                    end
                end
            end
        end
        for i in 1:length(natural_sequences[1,:])
            for j in 1:21          
                if j==1
                    j2=1
                elseif j==2
                    j2=2
                elseif j==3
                    j2=3
                elseif j==4
                    j2=4
                elseif j==5
                    j2=5
                elseif j==6
                    j2=6
                elseif j==7
                    j2=7
                elseif j==8
                    j2=8
                elseif j==9
                    j2=9
                elseif j==10
                    j2=10
                elseif j==11
                    j2=11
                elseif j==12
                    j2=12
                elseif j==13
                    j2=13
                elseif j==14
                    j2=14
                elseif j==15
                    j2=15
                elseif j==16
                    j2=16
                elseif j==17
                    j2=17
                elseif j==18
                    j2=18
                elseif j==19
                    j2=19
                elseif j==20
                    j2=20
                elseif j==21
                    j2=0
                end
                opo=h[21*(i-1)+j]
                write(f,"\nh $(i-1) $(j2) $opo" )
            end
        end
    end
end
# Out:
# print_model_to_file_prot (generic function with 1 method)

# %%
filename = "../saved_models/model_cumulative0.3_stop0.9_pseudocount0.5_init_pscount0.01_nbook3.txt"
print_model_to_file_prot(natural_sequences, Jij, h, filename)

# %% [markdown]
# <font size="3">The model obtained has a performance comparable to the fully connected DCA while having just ~20% of its connectivity. The entropy of the model is 35.08. This means that it is able to generate e³⁵ (3.5x10¹⁵) different 55-102 segments for the RF00379 family. \
# Now we can test our artificial sequences. We do the classical statistical check of the PCA projection and the two-point correlation representation. \
# We test the performance of our model against the one of the Covariance Model. The CM model only contains trivial one-point and secondary information so our model must do better than it. </font>

# %%
cm_sequences = rna_cm_model_generation(0.8,0.05,7000,natural_sequences,ss_contact_matrix);

# %%
plot_stat_check(natural_sequences, generated_sequences, cm_sequences)

# %% [markdown]
# <font size="3">The E.A.A. artificial molecules are practically statistically indistinguishable from the natural ones. We see that they have a very similar PCA projection (artificial one seems richer just because we have more artificial sequences than natural ones) while Covariance Model fails to capture the details of the distribution.
#     The selected model has almost a perfect two-point statistics for all site pairs while the CM model only captures it for the ones involved in secondary structure contacts. \
#      </font>

# %% [markdown]
# <font size="3">The interpretability is one of the main reasons in our quest to find parsimonious generative models. Now that we are sure we obtained a good generative model with relatively few parameters we can try to interprete them. \
# Dividing the added edges in secondary structure contacts, 3D contacts we have:

# %%
edge_interpretation_plot(len,ss_contact_matrix,tertiary_contact_matrix,edge_list[1:50,:])

# %% [markdown]
# <font size="3">We see that the secondary structure contacts are taken in the first few iteration. We have lot of neighbouring sites probably due to philogenic effects. It is striking that we see some 3D contacts (in particular around site 40) before the NONE edges. This
# suggests that our algorithm effectively captures some information about the tertiary structure. \
# Those results, that are far more general than this simple example, suggest that the added edges have a co-evolutionary interpretation.

# %% [markdown]
# <font size="3">
# This notebook serves as an example of the application of the techniques described in the main text.
