# %% [markdown]
# # Edge Addition Algorithm - simple implementation example

# %% [markdown]
# <font size="3">Run time is around ~5 minutes with the default input. \
# \
# In this example we will use the E.A.A. model to build a low-connectivity DCA model. \
# The information that we have about the training RNA family consists in: the sequence alignment and the consenus secondary structure (both trough the Covariance Model) and the 3D contacts trough the PDB file. </font>

# %%
include("../src/FCSeqTools.jl");

# %% [markdown]
# <font size="3">Here is an example of  RF00379 molecule and its associated consensus secondary structure. \
# To make the execution faster we will not generate full lenght molecules but just a portion from nucleotide 55 to 102. </font>

# %%
natural_sequences = do_number_matrix_prot(do_letter_matrix("../data/CM_130530_MC.fasta"), 0.2);

#Betalactamases_VIM-NDM

# %% [markdown]
# <font size="3">Here is a segment example with its associated secondary structure. \
# The database has a different size because the data-cleaning procedure depends on the region selected. \
# Now we will run the E.A.A. building up our ineraction netwotk edge by edge till we reach a good performance generative model. \
# At each iteration the algorithm reports: the added edge, the iteration number, the number of total added edges and the connectivity percentace of the fully connected case.\
# Each 15 iterations the algorithm reports: the model score (Pearson between natural and artificial two-point correlations), the model mean energy, the model partition function and the model entropy.

# %%
using Random

n_step = 100_000
method = "largest_component"
fraction = 0.1
stop = 0.95
pseudo_count = 0.2
s = time()
Random.seed!(2) 
notebook = "nb1"

family_name = "CM_alignment" #"Betalactamases"
test_folder = "three_different_pseudocounts"
score, likelihood_gain, generated_sequences, Jij, h, contact_list, site_degree, edge_list, single_likelihood_gain_vector, path = E_A_A(21, n_step, pseudo_count, 12000, natural_sequences,"example_output.txt", family_name, test_folder, method, notebook, fraction, stop); 

s = time() - s

# SAVE DATA ##################################################################################
using JLD
init_pseudo_count = 0.01
#folder_name = "../training/" * method * string(fraction) * "_stop=" * string(stop) * "_reg="*string(pseudo_count)*"_h_ps-count=" * string(init_pseudo_count) * "nbook="*notebook
JLD.save(path*"/"*"score.jld","data", score)
JLD.save(path*"/"*"likelihood_gain.jld","data", likelihood_gain)
JLD.save(path*"/"*"generated_sequences.jld","data", generated_sequences)
JLD.save(path*"/"*"Jij.jld","data", Jij)
JLD.save(path*"/"*"h.jld","data", h)
JLD.save(path*"/"*"contact_list.jld","data", contact_list)
JLD.save(path*"/"*"site_degree.jld","data", site_degree)
JLD.save(path*"/"*"edge_list.jld","data", edge_list)
# Out:
# saving data in:../training/CM_alignment/largest_component/three_different_pseudocounts/largest_component_reg=0.2_nb1
# Fully connected model has 4560 edges, 2010960 elements and a score around ~ 0.95
#
#  iteration = 10    edges: 7,   elements: 10,   edge complexity: 0.15 %,  elements complexity: 0.0 %
#
#  iteration = 20   edges: 13,   elements: 20,   edge complexity: 0.29 %,  elements complexity: 0.0 %
#
#  iteration = 30   edges: 20,   elements: 30,   edge complexity: 0.44 %,  elements complexity: 0.0 %
#
#  iteration = 40   edges: 23,   elements: 40,   edge complexity: 0.5 %,  elements complexity: 0.0 %
#
#  iteration = 50   edges: 26,   elements: 50,   edge complexity: 0.57 %,  elements complexity: 0.0 %
#
#  iteration = 60   edges: 31,   elements: 60,   edge complexity: 0.68 %,  elements complexity: 0.0 %
#
#  iteration = 70   edges: 34,   elements: 70,   edge complexity: 0.75 %,  elements complexity: 0.0 %
#
#  iteration = 80   edges: 40,   elements: 80,   edge complexity: 0.88 %,  elements complexity: 0.0 %
#
#  iteration = 90   edges: 46,   elements: 90,   edge complexity: 1.01 %,  elements complexity: 0.0 %
#
#  iteration = 100   edges: 51,   elements: 100,   edge complexity: 1.12 %,  elements complexity: 0.0 %
#
#  iteration = 110   edges: 56,   elements: 110,   edge complexity: 1.23 %,  elements complexity: 0.01 %
#
#  iteration = 120   edges: 59,   elements: 120,   edge complexity: 1.29 %,  elements complexity: 0.01 %
#
#  iteration = 130   edges: 63,   elements: 130,   edge complexity: 1.38 %,  elements complexity: 0.01 %
#
#  iteration = 140   edges: 67,   elements: 140,   edge complexity: 1.47 %,  elements complexity: 0.01 %
#
#  iteration = 150   edges: 69,   elements: 150,   edge complexity: 1.51 %,  elements complexity: 0.01 %
#
#  iteration = 160   edges: 73,   elements: 160,   edge complexity: 1.6 %,  elements complexity: 0.01 %
#
#  iteration = 170   edges: 78,   elements: 170,   edge complexity: 1.71 %,  elements complexity: 0.01 %
#
#  iteration = 180   edges: 83,   elements: 179,   edge complexity: 1.82 %,  elements complexity: 0.01 %
#
#  iteration = 190   edges: 86,   elements: 189,   edge complexity: 1.89 %,  elements complexity: 0.01 %
#
#  iteration = 200   edges: 91,   elements: 199,   edge complexity: 2.0 %,  elements complexity: 0.01 %
#
#  iteration = 210   edges: 95,   elements: 209,   edge complexity: 2.08 %,  elements complexity: 0.01 %
#
#  iteration = 220   edges: 98,   elements: 219,   edge complexity: 2.15 %,  elements complexity: 0.01 %
#
#  iteration = 230   edges: 104,   elements: 229,   edge complexity: 2.28 %,  elements complexity: 0.01 %
#
#  iteration = 240   edges: 108,   elements: 239,   edge complexity: 2.37 %,  elements complexity: 0.01 %
#
#  iteration = 250   edges: 110,   elements: 249,   edge complexity: 2.41 %,  elements complexity: 0.01 %
#
#  iteration = 260   edges: 111,   elements: 259,   edge complexity: 2.43 %,  elements complexity: 0.01 %
#
#  iteration = 270   edges: 113,   elements: 269,   edge complexity: 2.48 %,  elements complexity: 0.01 %
#
#  iteration = 280   edges: 120,   elements: 279,   edge complexity: 2.63 %,  elements complexity: 0.01 %
#
#  iteration = 290   edges: 124,   elements: 289,   edge complexity: 2.72 %,  elements complexity: 0.01 %
#
#  iteration = 300   edges: 127,   elements: 299,   edge complexity: 2.79 %,  elements complexity: 0.01 %
#
#  iteration = 310   edges: 127,   elements: 309,   edge complexity: 2.79 %,  elements complexity: 0.02 %
#
#  iteration = 320   edges: 128,   elements: 319,   edge complexity: 2.81 %,  elements complexity: 0.02 %
#
#  iteration = 330   edges: 129,   elements: 328,   edge complexity: 2.83 %,  elements complexity: 0.02 %
#
#  iteration = 340   edges: 134,   elements: 338,   edge complexity: 2.94 %,  elements complexity: 0.02 %
#
#  iteration = 350   edges: 135,   elements: 348,   edge complexity: 2.96 %,  elements complexity: 0.02 %
#
#  iteration = 360   edges: 138,   elements: 358,   edge complexity: 3.03 %,  elements complexity: 0.02 %
#
#  iteration = 370   edges: 141,   elements: 368,   edge complexity: 3.09 %,  elements complexity: 0.02 %
#
#  iteration = 380   edges: 145,   elements: 378,   edge complexity: 3.18 %,  elements complexity: 0.02 %
#
#  iteration = 390   edges: 149,   elements: 388,   edge complexity: 3.27 %,  elements complexity: 0.02 %
#
#  iteration = 400   edges: 151,   elements: 398,   edge complexity: 3.31 %,  elements complexity: 0.02 %
#
#  iteration = 410   edges: 155,   elements: 408,   edge complexity: 3.4 %,  elements complexity: 0.02 %
#
#  iteration = 420   edges: 157,   elements: 418,   edge complexity: 3.44 %,  elements complexity: 0.02 %
#
#  iteration = 430   edges: 161,   elements: 428,   edge complexity: 3.53 %,  elements complexity: 0.02 %
#
#  iteration = 440   edges: 164,   elements: 438,   edge complexity: 3.6 %,  elements complexity: 0.02 %
#
#  iteration = 450   edges: 168,   elements: 448,   edge complexity: 3.68 %,  elements complexity: 0.02 %
#
#  iteration = 460   edges: 173,   elements: 458,   edge complexity: 3.79 %,  elements complexity: 0.02 %
#
#  iteration = 470   edges: 176,   elements: 468,   edge complexity: 3.86 %,  elements complexity: 0.02 %
#
#  iteration = 480   edges: 177,   elements: 477,   edge complexity: 3.88 %,  elements complexity: 0.02 %
#
#  iteration = 490   edges: 179,   elements: 486,   edge complexity: 3.93 %,  elements complexity: 0.02 %
#
#  iteration = 500   edges: 183,   elements: 496,   edge complexity: 4.01 %,  elements complexity: 0.02 %
#
#  iteration = 510   edges: 187,   elements: 506,   edge complexity: 4.1 %,  elements complexity: 0.03 %
#
#  iteration = 520   edges: 190,   elements: 516,   edge complexity: 4.17 %,  elements complexity: 0.03 %
#
#  iteration = 530   edges: 193,   elements: 526,   edge complexity: 4.23 %,  elements complexity: 0.03 %
#
#  iteration = 540   edges: 198,   elements: 536,   edge complexity: 4.34 %,  elements complexity: 0.03 %
#
#  iteration = 550   edges: 201,   elements: 546,   edge complexity: 4.41 %,  elements complexity: 0.03 %
#
#  iteration = 560   edges: 204,   elements: 556,   edge complexity: 4.47 %,  elements complexity: 0.03 %
#
#  iteration = 570   edges: 208,   elements: 566,   edge complexity: 4.56 %,  elements complexity: 0.03 %
#
#  iteration = 580   edges: 212,   elements: 576,   edge complexity: 4.65 %,  elements complexity: 0.03 %
#
#  iteration = 590   edges: 216,   elements: 586,   edge complexity: 4.74 %,  elements complexity: 0.03 %
#
#  iteration = 600   edges: 218,   elements: 596,   edge complexity: 4.78 %,  elements complexity: 0.03 %
#
#  iteration = 610   edges: 220,   elements: 606,   edge complexity: 4.82 %,  elements complexity: 0.03 %
#
#  iteration = 620   edges: 224,   elements: 616,   edge complexity: 4.91 %,  elements complexity: 0.03 %
#
#  iteration = 630   edges: 225,   elements: 626,   edge complexity: 4.93 %,  elements complexity: 0.03 %
#
#  iteration = 640   edges: 230,   elements: 636,   edge complexity: 5.04 %,  elements complexity: 0.03 %
#
#  iteration = 650   edges: 231,   elements: 646,   edge complexity: 5.07 %,  elements complexity: 0.03 %
#
#  iteration = 660   edges: 234,   elements: 656,   edge complexity: 5.13 %,  elements complexity: 0.03 %
#
#  iteration = 670   edges: 237,   elements: 666,   edge complexity: 5.2 %,  elements complexity: 0.03 %
#
#  iteration = 680   edges: 240,   elements: 676,   edge complexity: 5.26 %,  elements complexity: 0.03 %
#
#  iteration = 690   edges: 244,   elements: 686,   edge complexity: 5.35 %,  elements complexity: 0.03 %
#
#  iteration = 700   edges: 249,   elements: 696,   edge complexity: 5.46 %,  elements complexity: 0.03 %
#
#  iteration = 710   edges: 253,   elements: 706,   edge complexity: 5.55 %,  elements complexity: 0.04 %
#
#  iteration = 720   edges: 257,   elements: 716,   edge complexity: 5.64 %,  elements complexity: 0.04 %
#
#  iteration = 730   edges: 260,   elements: 726,   edge complexity: 5.7 %,  elements complexity: 0.04 %
#
#  iteration = 740   edges: 264,   elements: 736,   edge complexity: 5.79 %,  elements complexity: 0.04 %
#
#  iteration = 750   edges: 269,   elements: 746,   edge complexity: 5.9 %,  elements complexity: 0.04 %
#
#  iteration = 760   edges: 272,   elements: 756,   edge complexity: 5.96 %,  elements complexity: 0.04 %
#
#  iteration = 770   edges: 275,   elements: 766,   edge complexity: 6.03 %,  elements complexity: 0.04 %
#
#  iteration = 780   edges: 282,   elements: 776,   edge complexity: 6.18 %,  elements complexity: 0.04 %
#
#  iteration = 790   edges: 283,   elements: 786,   edge complexity: 6.21 %,  elements complexity: 0.04 %
#
#  iteration = 800   edges: 285,   elements: 796,   edge complexity: 6.25 %,  elements complexity: 0.04 %
#
#  iteration = 810   edges: 288,   elements: 806,   edge complexity: 6.32 %,  elements complexity: 0.04 %
#
#  iteration = 820   edges: 290,   elements: 816,   edge complexity: 6.36 %,  elements complexity: 0.04 %
#
#  iteration = 830   edges: 290,   elements: 826,   edge complexity: 6.36 %,  elements complexity: 0.04 %
#
#  iteration = 840   edges: 294,   elements: 836,   edge complexity: 6.45 %,  elements complexity: 0.04 %
#
#  iteration = 850   edges: 300,   elements: 846,   edge complexity: 6.58 %,  elements complexity: 0.04 %
#
#  iteration = 860   edges: 305,   elements: 856,   edge complexity: 6.69 %,  elements complexity: 0.04 %
#
#  iteration = 870   edges: 307,   elements: 865,   edge complexity: 6.73 %,  elements complexity: 0.04 %
#
#  iteration = 880   edges: 310,   elements: 875,   edge complexity: 6.8 %,  elements complexity: 0.04 %
#
#  iteration = 890   edges: 316,   elements: 885,   edge complexity: 6.93 %,  elements complexity: 0.04 %
#
#  iteration = 900   edges: 319,   elements: 895,   edge complexity: 7.0 %,  elements complexity: 0.04 %
#
#  iteration = 910   edges: 320,   elements: 905,   edge complexity: 7.02 %,  elements complexity: 0.05 %
#
#  iteration = 920   edges: 324,   elements: 915,   edge complexity: 7.11 %,  elements complexity: 0.05 %
#
#  iteration = 930   edges: 329,   elements: 925,   edge complexity: 7.21 %,  elements complexity: 0.05 %
#
#  iteration = 940   edges: 333,   elements: 935,   edge complexity: 7.3 %,  elements complexity: 0.05 %
#
#  iteration = 950   edges: 337,   elements: 945,   edge complexity: 7.39 %,  elements complexity: 0.05 %
#
#  iteration = 960   edges: 341,   elements: 955,   edge complexity: 7.48 %,  elements complexity: 0.05 %
#
#  iteration = 970   edges: 342,   elements: 965,   edge complexity: 7.5 %,  elements complexity: 0.05 %
#
#  iteration = 980   edges: 345,   elements: 975,   edge complexity: 7.57 %,  elements complexity: 0.05 %
#
#  iteration = 990   edges: 348,   elements: 985,   edge complexity: 7.63 %,  elements complexity: 0.05 %
#
#  iteration = 1000   edges: 352,   elements: 995,   edge complexity: 7.72 %,  elements complexity: 0.05 %
#
#  iteration = 1010   edges: 357,   elements: 1005,   edge complexity: 7.83 %,  elements complexity: 0.05 %
#
#  iteration = 1020   edges: 358,   elements: 1015,   edge complexity: 7.85 %,  elements complexity: 0.05 %
#
#  iteration = 1030   edges: 361,   elements: 1025,   edge complexity: 7.92 %,  elements complexity: 0.05 %
#
#  iteration = 1040   edges: 365,   elements: 1035,   edge complexity: 8.0 %,  elements complexity: 0.05 %
#
#  iteration = 1050   edges: 367,   elements: 1045,   edge complexity: 8.05 %,  elements complexity: 0.05 %
#
#  iteration = 1060   edges: 372,   elements: 1055,   edge complexity: 8.16 %,  elements complexity: 0.05 %
#
#  iteration = 1070   edges: 374,   elements: 1065,   edge complexity: 8.2 %,  elements complexity: 0.05 %
#
#  iteration = 1080   edges: 375,   elements: 1074,   edge complexity: 8.22 %,  elements complexity: 0.05 %
#
#  iteration = 1090   edges: 382,   elements: 1084,   edge complexity: 8.38 %,  elements complexity: 0.05 %
#
#  iteration = 1100   edges: 385,   elements: 1094,   edge complexity: 8.44 %,  elements complexity: 0.05 %
#
#  iteration = 1110   edges: 388,   elements: 1104,   edge complexity: 8.51 %,  elements complexity: 0.05 %
#
#  iteration = 1120   edges: 389,   elements: 1113,   edge complexity: 8.53 %,  elements complexity: 0.06 %
#
#  iteration = 1130   edges: 393,   elements: 1123,   edge complexity: 8.62 %,  elements complexity: 0.06 %
#
#  iteration = 1140   edges: 396,   elements: 1133,   edge complexity: 8.68 %,  elements complexity: 0.06 %
#
#  iteration = 1150   edges: 400,   elements: 1143,   edge complexity: 8.77 %,  elements complexity: 0.06 %
#
#  iteration = 1160   edges: 403,   elements: 1152,   edge complexity: 8.84 %,  elements complexity: 0.06 %
#
#  iteration = 1170   edges: 408,   elements: 1162,   edge complexity: 8.95 %,  elements complexity: 0.06 %
#
#  iteration = 1180   edges: 412,   elements: 1171,   edge complexity: 9.04 %,  elements complexity: 0.06 %
#
#  iteration = 1190   edges: 415,   elements: 1181,   edge complexity: 9.1 %,  elements complexity: 0.06 %
#
#  iteration = 1200   edges: 420,   elements: 1191,   edge complexity: 9.21 %,  elements complexity: 0.06 %
#
#  iteration = 1210   edges: 423,   elements: 1201,   edge complexity: 9.28 %,  elements complexity: 0.06 %
#
#  iteration = 1220   edges: 429,   elements: 1211,   edge complexity: 9.41 %,  elements complexity: 0.06 %
#
#  iteration = 1230   edges: 431,   elements: 1221,   edge complexity: 9.45 %,  elements complexity: 0.06 %
#
#  iteration = 1240   edges: 433,   elements: 1231,   edge complexity: 9.5 %,  elements complexity: 0.06 %
#
#  iteration = 1250   edges: 438,   elements: 1241,   edge complexity: 9.61 %,  elements complexity: 0.06 %
#
#  iteration = 1260   edges: 440,   elements: 1250,   edge complexity: 9.65 %,  elements complexity: 0.06 %
#
#  iteration = 1270   edges: 444,   elements: 1260,   edge complexity: 9.74 %,  elements complexity: 0.06 %
#
#  iteration = 1280   edges: 448,   elements: 1270,   edge complexity: 9.82 %,  elements complexity: 0.06 %
#
#  iteration = 1290   edges: 454,   elements: 1280,   edge complexity: 9.96 %,  elements complexity: 0.06 %
#
#  iteration = 1300   edges: 457,   elements: 1290,   edge complexity: 10.02 %,  elements complexity: 0.06 %
#
#  iteration = 1310   edges: 462,   elements: 1300,   edge complexity: 10.13 %,  elements complexity: 0.06 %
#
#  iteration = 1320   edges: 465,   elements: 1309,   edge complexity: 10.2 %,  elements complexity: 0.07 %
#
#  iteration = 1330   edges: 470,   elements: 1319,   edge complexity: 10.31 %,  elements complexity: 0.07 %
#
#  iteration = 1340   edges: 472,   elements: 1329,   edge complexity: 10.35 %,  elements complexity: 0.07 %
#
#  iteration = 1350   edges: 474,   elements: 1339,   edge complexity: 10.39 %,  elements complexity: 0.07 %
#
#  iteration = 1360   edges: 480,   elements: 1349,   edge complexity: 10.53 %,  elements complexity: 0.07 %
#
#  iteration = 1370   edges: 483,   elements: 1359,   edge complexity: 10.59 %,  elements complexity: 0.07 %
#
#  iteration = 1380   edges: 484,   elements: 1369,   edge complexity: 10.61 %,  elements complexity: 0.07 %
#
#  iteration = 1390   edges: 487,   elements: 1378,   edge complexity: 10.68 %,  elements complexity: 0.07 %
#
#  iteration = 1400   edges: 491,   elements: 1388,   edge complexity: 10.77 %,  elements complexity: 0.07 %
#
#  iteration = 1410   edges: 495,   elements: 1398,   edge complexity: 10.86 %,  elements complexity: 0.07 %
#
#  iteration = 1420   edges: 498,   elements: 1407,   edge complexity: 10.92 %,  elements complexity: 0.07 %
#
#  iteration = 1430   edges: 501,   elements: 1417,   edge complexity: 10.99 %,  elements complexity: 0.07 %
#
#  iteration = 1440   edges: 505,   elements: 1427,   edge complexity: 11.07 %,  elements complexity: 0.07 %
#
#  iteration = 1450   edges: 507,   elements: 1437,   edge complexity: 11.12 %,  elements complexity: 0.07 %
#
#  iteration = 1460   edges: 511,   elements: 1446,   edge complexity: 11.21 %,  elements complexity: 0.07 %
#
#  iteration = 1470   edges: 514,   elements: 1456,   edge complexity: 11.27 %,  elements complexity: 0.07 %
#
#  iteration = 1480   edges: 521,   elements: 1466,   edge complexity: 11.43 %,  elements complexity: 0.07 %
#
#  iteration = 1490   edges: 522,   elements: 1476,   edge complexity: 11.45 %,  elements complexity: 0.07 %
#
#  iteration = 1500   edges: 526,   elements: 1486,   edge complexity: 11.54 %,  elements complexity: 0.07 %
#
#  iteration = 1510   edges: 530,   elements: 1496,   edge complexity: 11.62 %,  elements complexity: 0.07 %
#
#  iteration = 1520   edges: 531,   elements: 1506,   edge complexity: 11.64 %,  elements complexity: 0.07 %
#
#  iteration = 1530   edges: 536,   elements: 1516,   edge complexity: 11.75 %,  elements complexity: 0.08 %
#
#  iteration = 1540   edges: 536,   elements: 1525,   edge complexity: 11.75 %,  elements complexity: 0.08 %
#
#  iteration = 1550   edges: 540,   elements: 1534,   edge complexity: 11.84 %,  elements complexity: 0.08 %
#
#  iteration = 1560   edges: 541,   elements: 1544,   edge complexity: 11.86 %,  elements complexity: 0.08 %
#
#  iteration = 1570   edges: 542,   elements: 1554,   edge complexity: 11.89 %,  elements complexity: 0.08 %
#
#  iteration = 1580   edges: 543,   elements: 1564,   edge complexity: 11.91 %,  elements complexity: 0.08 %
#
#  iteration = 1590   edges: 544,   elements: 1574,   edge complexity: 11.93 %,  elements complexity: 0.08 %
#
#  iteration = 1600   edges: 545,   elements: 1584,   edge complexity: 11.95 %,  elements complexity: 0.08 %
#
#  iteration = 1610   edges: 546,   elements: 1594,   edge complexity: 11.97 %,  elements complexity: 0.08 %
#
#  iteration = 1620   edges: 546,   elements: 1604,   edge complexity: 11.97 %,  elements complexity: 0.08 %
#
#  iteration = 1630   edges: 548,   elements: 1613,   edge complexity: 12.02 %,  elements complexity: 0.08 %
#
#  iteration = 1640   edges: 550,   elements: 1623,   edge complexity: 12.06 %,  elements complexity: 0.08 %
#
#  iteration = 1650   edges: 555,   elements: 1633,   edge complexity: 12.17 %,  elements complexity: 0.08 %
#
#  iteration = 1660   edges: 559,   elements: 1643,   edge complexity: 12.26 %,  elements complexity: 0.08 %
#
#  iteration = 1670   edges: 562,   elements: 1653,   edge complexity: 12.32 %,  elements complexity: 0.08 %
#
#  iteration = 1680   edges: 566,   elements: 1663,   edge complexity: 12.41 %,  elements complexity: 0.08 %
#
#  iteration = 1690   edges: 569,   elements: 1673,   edge complexity: 12.48 %,  elements complexity: 0.08 %
#
#  iteration = 1700   edges: 572,   elements: 1683,   edge complexity: 12.54 %,  elements complexity: 0.08 %
#
#  iteration = 1710   edges: 575,   elements: 1693,   edge complexity: 12.61 %,  elements complexity: 0.08 %
#
#  iteration = 1720   edges: 578,   elements: 1702,   edge complexity: 12.68 %,  elements complexity: 0.08 %
#
#  iteration = 1730   edges: 581,   elements: 1712,   edge complexity: 12.74 %,  elements complexity: 0.09 %
#
#  iteration = 1740   edges: 584,   elements: 1721,   edge complexity: 12.81 %,  elements complexity: 0.09 %
#
#  iteration = 1750   edges: 585,   elements: 1731,   edge complexity: 12.83 %,  elements complexity: 0.09 %
#
#  iteration = 1760   edges: 588,   elements: 1741,   edge complexity: 12.89 %,  elements complexity: 0.09 %
#
#  iteration = 1770   edges: 590,   elements: 1751,   edge complexity: 12.94 %,  elements complexity: 0.09 %
#
#  iteration = 1780   edges: 592,   elements: 1761,   edge complexity: 12.98 %,  elements complexity: 0.09 %
#
#  iteration = 1790   edges: 596,   elements: 1771,   edge complexity: 13.07 %,  elements complexity: 0.09 %
#
#  iteration = 1800   edges: 597,   elements: 1780,   edge complexity: 13.09 %,  elements complexity: 0.09 %
#
#  iteration = 1810   edges: 600,   elements: 1790,   edge complexity: 13.16 %,  elements complexity: 0.09 %
#
#  iteration = 1820   edges: 600,   elements: 1800,   edge complexity: 13.16 %,  elements complexity: 0.09 %
#
#  iteration = 1830   edges: 603,   elements: 1810,   edge complexity: 13.22 %,  elements complexity: 0.09 %
#
#  iteration = 1840   edges: 608,   elements: 1820,   edge complexity: 13.33 %,  elements complexity: 0.09 %
#
#  iteration = 1850   edges: 609,   elements: 1830,   edge complexity: 13.36 %,  elements complexity: 0.09 %
#
#  iteration = 1860   edges: 611,   elements: 1840,   edge complexity: 13.4 %,  elements complexity: 0.09 %
#
#  iteration = 1870   edges: 614,   elements: 1850,   edge complexity: 13.46 %,  elements complexity: 0.09 %
#
#  iteration = 1880   edges: 617,   elements: 1860,   edge complexity: 13.53 %,  elements complexity: 0.09 %
#
#  iteration = 1890   edges: 619,   elements: 1869,   edge complexity: 13.57 %,  elements complexity: 0.09 %
#
#  iteration = 1900   edges: 621,   elements: 1879,   edge complexity: 13.62 %,  elements complexity: 0.09 %
#
#  iteration = 1910   edges: 623,   elements: 1889,   edge complexity: 13.66 %,  elements complexity: 0.09 %
#
#  iteration = 1920   edges: 624,   elements: 1899,   edge complexity: 13.68 %,  elements complexity: 0.09 %
#
#  iteration = 1930   edges: 624,   elements: 1908,   edge complexity: 13.68 %,  elements complexity: 0.09 %
#
#  iteration = 1940   edges: 625,   elements: 1917,   edge complexity: 13.71 %,  elements complexity: 0.1 %
#
#  iteration = 1950   edges: 627,   elements: 1925,   edge complexity: 13.75 %,  elements complexity: 0.1 %
#
#  iteration = 1960   edges: 629,   elements: 1934,   edge complexity: 13.79 %,  elements complexity: 0.1 %
#
#  iteration = 1970   edges: 632,   elements: 1944,   edge complexity: 13.86 %,  elements complexity: 0.1 %
#
#  iteration = 1980   edges: 636,   elements: 1954,   edge complexity: 13.95 %,  elements complexity: 0.1 %
#
#  iteration = 1990   edges: 638,   elements: 1964,   edge complexity: 13.99 %,  elements complexity: 0.1 %
#
#  iteration = 2000   edges: 640,   elements: 1974,   edge complexity: 14.04 %,  elements complexity: 0.1 %
#
#  iteration = 2010   edges: 641,   elements: 1984,   edge complexity: 14.06 %,  elements complexity: 0.1 %
#
#  iteration = 2020   edges: 645,   elements: 1994,   edge complexity: 14.14 %,  elements complexity: 0.1 %
#
#  iteration = 2030   edges: 648,   elements: 2004,   edge complexity: 14.21 %,  elements complexity: 0.1 %
#
#  iteration = 2040   edges: 649,   elements: 2014,   edge complexity: 14.23 %,  elements complexity: 0.1 %
#
#  iteration = 2050   edges: 652,   elements: 2024,   edge complexity: 14.3 %,  elements complexity: 0.1 %
#
#  iteration = 2060   edges: 654,   elements: 2034,   edge complexity: 14.34 %,  elements complexity: 0.1 %
#
#  iteration = 2070   edges: 657,   elements: 2044,   edge complexity: 14.41 %,  elements complexity: 0.1 %
#
#  iteration = 2080   edges: 661,   elements: 2054,   edge complexity: 14.5 %,  elements complexity: 0.1 %
#
#  iteration = 2090   edges: 664,   elements: 2064,   edge complexity: 14.56 %,  elements complexity: 0.1 %
#
#  iteration = 2100   edges: 666,   elements: 2073,   edge complexity: 14.61 %,  elements complexity: 0.1 %
#
#  iteration = 2110   edges: 671,   elements: 2082,   edge complexity: 14.71 %,  elements complexity: 0.1 %
#
#  iteration = 2120   edges: 673,   elements: 2092,   edge complexity: 14.76 %,  elements complexity: 0.1 %
#
#  iteration = 2130   edges: 673,   elements: 2102,   edge complexity: 14.76 %,  elements complexity: 0.1 %
#
#  iteration = 2140   edges: 675,   elements: 2112,   edge complexity: 14.8 %,  elements complexity: 0.11 %
#
#  iteration = 2150   edges: 676,   elements: 2121,   edge complexity: 14.82 %,  elements complexity: 0.11 %
#
#  iteration = 2160   edges: 678,   elements: 2131,   edge complexity: 14.87 %,  elements complexity: 0.11 %
#
#  iteration = 2170   edges: 680,   elements: 2141,   edge complexity: 14.91 %,  elements complexity: 0.11 %
#
#  iteration = 2180   edges: 682,   elements: 2151,   edge complexity: 14.96 %,  elements complexity: 0.11 %
#
#  iteration = 2190   edges: 683,   elements: 2161,   edge complexity: 14.98 %,  elements complexity: 0.11 %
#
#  iteration = 2200   edges: 686,   elements: 2171,   edge complexity: 15.04 %,  elements complexity: 0.11 %
#
#  iteration = 2210   edges: 687,   elements: 2180,   edge complexity: 15.07 %,  elements complexity: 0.11 %
#
#  iteration = 2220   edges: 689,   elements: 2190,   edge complexity: 15.11 %,  elements complexity: 0.11 %
#
#  iteration = 2230   edges: 692,   elements: 2199,   edge complexity: 15.18 %,  elements complexity: 0.11 %
#
#  iteration = 2240   edges: 695,   elements: 2209,   edge complexity: 15.24 %,  elements complexity: 0.11 %
#
#  iteration = 2250   edges: 699,   elements: 2218,   edge complexity: 15.33 %,  elements complexity: 0.11 %
#
#  iteration = 2260   edges: 701,   elements: 2228,   edge complexity: 15.37 %,  elements complexity: 0.11 %
#
#  iteration = 2270   edges: 706,   elements: 2238,   edge complexity: 15.48 %,  elements complexity: 0.11 %
#
#  iteration = 2280   edges: 709,   elements: 2248,   edge complexity: 15.55 %,  elements complexity: 0.11 %
#
#  iteration = 2290   edges: 710,   elements: 2258,   edge complexity: 15.57 %,  elements complexity: 0.11 %
#
#  iteration = 2300   edges: 711,   elements: 2268,   edge complexity: 15.59 %,  elements complexity: 0.11 %
#
#  iteration = 2310   edges: 715,   elements: 2278,   edge complexity: 15.68 %,  elements complexity: 0.11 %
#
#  iteration = 2320   edges: 717,   elements: 2288,   edge complexity: 15.72 %,  elements complexity: 0.11 %
#
#  iteration = 2330   edges: 719,   elements: 2298,   edge complexity: 15.77 %,  elements complexity: 0.11 %
#
#  iteration = 2340   edges: 723,   elements: 2308,   edge complexity: 15.86 %,  elements complexity: 0.11 %
#
#  iteration = 2350   edges: 726,   elements: 2318,   edge complexity: 15.92 %,  elements complexity: 0.12 %
#
#  iteration = 2360   edges: 728,   elements: 2328,   edge complexity: 15.96 %,  elements complexity: 0.12 %
#
#  iteration = 2370   edges: 731,   elements: 2338,   edge complexity: 16.03 %,  elements complexity: 0.12 %
#
#  iteration = 2380   edges: 733,   elements: 2347,   edge complexity: 16.07 %,  elements complexity: 0.12 %
#
#  iteration = 2390   edges: 735,   elements: 2356,   edge complexity: 16.12 %,  elements complexity: 0.12 %
#
#  iteration = 2400   edges: 736,   elements: 2366,   edge complexity: 16.14 %,  elements complexity: 0.12 %
#
#  iteration = 2410   edges: 738,   elements: 2375,   edge complexity: 16.18 %,  elements complexity: 0.12 %
#
#  iteration = 2420   edges: 739,   elements: 2385,   edge complexity: 16.21 %,  elements complexity: 0.12 %
#
#  iteration = 2430   edges: 742,   elements: 2395,   edge complexity: 16.27 %,  elements complexity: 0.12 %
#
#  iteration = 2440   edges: 745,   elements: 2404,   edge complexity: 16.34 %,  elements complexity: 0.12 %
#
#  iteration = 2450   edges: 747,   elements: 2414,   edge complexity: 16.38 %,  elements complexity: 0.12 %
#
#  iteration = 2460   edges: 748,   elements: 2423,   edge complexity: 16.4 %,  elements complexity: 0.12 %
#
#  iteration = 2470   edges: 753,   elements: 2433,   edge complexity: 16.51 %,  elements complexity: 0.12 %
#
#  iteration = 2480   edges: 755,   elements: 2443,   edge complexity: 16.56 %,  elements complexity: 0.12 %
#
#  iteration = 2490   edges: 757,   elements: 2453,   edge complexity: 16.6 %,  elements complexity: 0.12 %
#
#  iteration = 2500   edges: 759,   elements: 2462,   edge complexity: 16.64 %,  elements complexity: 0.12 %
#
#  iteration = 2510   edges: 760,   elements: 2471,   edge complexity: 16.67 %,  elements complexity: 0.12 %
#
#  iteration = 2520   edges: 762,   elements: 2480,   edge complexity: 16.71 %,  elements complexity: 0.12 %
#
#  iteration = 2530   edges: 766,   elements: 2490,   edge complexity: 16.8 %,  elements complexity: 0.12 %
#
#  iteration = 2540   edges: 769,   elements: 2500,   edge complexity: 16.86 %,  elements complexity: 0.12 %
#
#  iteration = 2550   edges: 771,   elements: 2510,   edge complexity: 16.91 %,  elements complexity: 0.12 %
#
#  iteration = 2560   edges: 773,   elements: 2520,   edge complexity: 16.95 %,  elements complexity: 0.13 %
#
#  iteration = 2570   edges: 774,   elements: 2530,   edge complexity: 16.97 %,  elements complexity: 0.13 %
#
#  iteration = 2580   edges: 777,   elements: 2540,   edge complexity: 17.04 %,  elements complexity: 0.13 %
#
#  iteration = 2590   edges: 778,   elements: 2550,   edge complexity: 17.06 %,  elements complexity: 0.13 %
#
#  iteration = 2600   edges: 778,   elements: 2560,   edge complexity: 17.06 %,  elements complexity: 0.13 %
#
#  iteration = 2610   edges: 781,   elements: 2570,   edge complexity: 17.13 %,  elements complexity: 0.13 %
#
#  iteration = 2620   edges: 784,   elements: 2580,   edge complexity: 17.19 %,  elements complexity: 0.13 %
#
#  iteration = 2630   edges: 785,   elements: 2590,   edge complexity: 17.21 %,  elements complexity: 0.13 %
#
#  iteration = 2640   edges: 786,   elements: 2600,   edge complexity: 17.24 %,  elements complexity: 0.13 %
#
#  iteration = 2650   edges: 788,   elements: 2610,   edge complexity: 17.28 %,  elements complexity: 0.13 %
#
#  iteration = 2660   edges: 788,   elements: 2620,   edge complexity: 17.28 %,  elements complexity: 0.13 %
#
#  iteration = 2670   edges: 789,   elements: 2630,   edge complexity: 17.3 %,  elements complexity: 0.13 %
#
#  iteration = 2680   edges: 792,   elements: 2640,   edge complexity: 17.37 %,  elements complexity: 0.13 %
#
#  iteration = 2690   edges: 794,   elements: 2650,   edge complexity: 17.41 %,  elements complexity: 0.13 %
#
#  iteration = 2700   edges: 797,   elements: 2660,   edge complexity: 17.48 %,  elements complexity: 0.13 %
#
#  iteration = 2710   edges: 799,   elements: 2670,   edge complexity: 17.52 %,  elements complexity: 0.13 %
#
#  iteration = 2720   edges: 800,   elements: 2680,   edge complexity: 17.54 %,  elements complexity: 0.13 %
#
#  iteration = 2730   edges: 803,   elements: 2690,   edge complexity: 17.61 %,  elements complexity: 0.13 %
#
#  iteration = 2740   edges: 805,   elements: 2698,   edge complexity: 17.65 %,  elements complexity: 0.13 %
#
#  iteration = 2750   edges: 807,   elements: 2708,   edge complexity: 17.7 %,  elements complexity: 0.13 %
#
#  iteration = 2760   edges: 808,   elements: 2718,   edge complexity: 17.72 %,  elements complexity: 0.14 %
#
#  iteration = 2770   edges: 811,   elements: 2728,   edge complexity: 17.79 %,  elements complexity: 0.14 %
#
#  iteration = 2780   edges: 814,   elements: 2738,   edge complexity: 17.85 %,  elements complexity: 0.14 %
#
#  iteration = 2790   edges: 816,   elements: 2748,   edge complexity: 17.89 %,  elements complexity: 0.14 %
#
#  iteration = 2800   edges: 819,   elements: 2758,   edge complexity: 17.96 %,  elements complexity: 0.14 %
#
#  iteration = 2810   edges: 821,   elements: 2768,   edge complexity: 18.0 %,  elements complexity: 0.14 %
#
#  iteration = 2820   edges: 826,   elements: 2778,   edge complexity: 18.11 %,  elements complexity: 0.14 %
#
#  iteration = 2830   edges: 828,   elements: 2788,   edge complexity: 18.16 %,  elements complexity: 0.14 %
#
#  iteration = 2840   edges: 828,   elements: 2798,   edge complexity: 18.16 %,  elements complexity: 0.14 %
#
#  iteration = 2850   edges: 831,   elements: 2808,   edge complexity: 18.22 %,  elements complexity: 0.14 %
#
#  iteration = 2860   edges: 833,   elements: 2818,   edge complexity: 18.27 %,  elements complexity: 0.14 %
#
#  iteration = 2870   edges: 833,   elements: 2828,   edge complexity: 18.27 %,  elements complexity: 0.14 %
#
#  iteration = 2880   edges: 833,   elements: 2838,   edge complexity: 18.27 %,  elements complexity: 0.14 %
#
#  iteration = 2890   edges: 834,   elements: 2847,   edge complexity: 18.29 %,  elements complexity: 0.14 %
#
#  iteration = 2900   edges: 837,   elements: 2857,   edge complexity: 18.36 %,  elements complexity: 0.14 %
#
#  iteration = 2910   edges: 839,   elements: 2867,   edge complexity: 18.4 %,  elements complexity: 0.14 %
#
#  iteration = 2920   edges: 840,   elements: 2877,   edge complexity: 18.42 %,  elements complexity: 0.14 %
#
#  iteration = 2930   edges: 842,   elements: 2887,   edge complexity: 18.46 %,  elements complexity: 0.14 %
#
#  iteration = 2940   edges: 842,   elements: 2897,   edge complexity: 18.46 %,  elements complexity: 0.14 %
#
#  iteration = 2950   edges: 844,   elements: 2907,   edge complexity: 18.51 %,  elements complexity: 0.14 %
#
#  iteration = 2960   edges: 845,   elements: 2917,   edge complexity: 18.53 %,  elements complexity: 0.15 %
#
#  iteration = 2970   edges: 846,   elements: 2927,   edge complexity: 18.55 %,  elements complexity: 0.15 %
#
#  iteration = 2980   edges: 848,   elements: 2937,   edge complexity: 18.6 %,  elements complexity: 0.15 %
#
#  iteration = 2990   edges: 851,   elements: 2947,   edge complexity: 18.66 %,  elements complexity: 0.15 %
#
#  iteration = 3000   edges: 853,   elements: 2957,   edge complexity: 18.71 %,  elements complexity: 0.15 %
#
#  iteration = 3010   edges: 854,   elements: 2967,   edge complexity: 18.73 %,  elements complexity: 0.15 %
#
#  iteration = 3020   edges: 854,   elements: 2977,   edge complexity: 18.73 %,  elements complexity: 0.15 %
#
#  iteration = 3030   edges: 855,   elements: 2987,   edge complexity: 18.75 %,  elements complexity: 0.15 %
#
#  iteration = 3040   edges: 858,   elements: 2997,   edge complexity: 18.82 %,  elements complexity: 0.15 %
#
#  iteration = 3050   edges: 859,   elements: 3007,   edge complexity: 18.84 %,  elements complexity: 0.15 %
#
#  iteration = 3060   edges: 860,   elements: 3017,   edge complexity: 18.86 %,  elements complexity: 0.15 %
#
#  iteration = 3070   edges: 860,   elements: 3027,   edge complexity: 18.86 %,  elements complexity: 0.15 %
#
#  iteration = 3080   edges: 861,   elements: 3037,   edge complexity: 18.88 %,  elements complexity: 0.15 %
#
#  iteration = 3090   edges: 862,   elements: 3047,   edge complexity: 18.9 %,  elements complexity: 0.15 %
#
#  iteration = 3100   edges: 864,   elements: 3057,   edge complexity: 18.95 %,  elements complexity: 0.15 %
#
#  iteration = 3110   edges: 867,   elements: 3067,   edge complexity: 19.01 %,  elements complexity: 0.15 %
#
#  iteration = 3120   edges: 870,   elements: 3077,   edge complexity: 19.08 %,  elements complexity: 0.15 %
#
#  iteration = 3130   edges: 871,   elements: 3087,   edge complexity: 19.1 %,  elements complexity: 0.15 %
#
#  iteration = 3140   edges: 872,   elements: 3097,   edge complexity: 19.12 %,  elements complexity: 0.15 %
#
#  iteration = 3150   edges: 875,   elements: 3107,   edge complexity: 19.19 %,  elements complexity: 0.15 %
#
#  iteration = 3160   edges: 878,   elements: 3117,   edge complexity: 19.25 %,  elements complexity: 0.16 %
#
#  iteration = 3170   edges: 879,   elements: 3127,   edge complexity: 19.28 %,  elements complexity: 0.16 %
#
#  iteration = 3180   edges: 882,   elements: 3137,   edge complexity: 19.34 %,  elements complexity: 0.16 %
#
#  iteration = 3190   edges: 883,   elements: 3147,   edge complexity: 19.36 %,  elements complexity: 0.16 %
#
#  iteration = 3200   edges: 885,   elements: 3156,   edge complexity: 19.41 %,  elements complexity: 0.16 %
#
#  iteration = 3210   edges: 886,   elements: 3166,   edge complexity: 19.43 %,  elements complexity: 0.16 %
#
#  iteration = 3220   edges: 888,   elements: 3176,   edge complexity: 19.47 %,  elements complexity: 0.16 %
#
#  iteration = 3230   edges: 892,   elements: 3186,   edge complexity: 19.56 %,  elements complexity: 0.16 %
#
#  iteration = 3240   edges: 894,   elements: 3196,   edge complexity: 19.61 %,  elements complexity: 0.16 %
#
#  iteration = 3250   edges: 895,   elements: 3206,   edge complexity: 19.63 %,  elements complexity: 0.16 %
#
#  iteration = 3260   edges: 897,   elements: 3216,   edge complexity: 19.67 %,  elements complexity: 0.16 %
#
#  iteration = 3270   edges: 899,   elements: 3226,   edge complexity: 19.71 %,  elements complexity: 0.16 %
#
#  iteration = 3280   edges: 901,   elements: 3236,   edge complexity: 19.76 %,  elements complexity: 0.16 %
#
#  iteration = 3290   edges: 904,   elements: 3246,   edge complexity: 19.82 %,  elements complexity: 0.16 %
#
#  iteration = 3300   edges: 905,   elements: 3256,   edge complexity: 19.85 %,  elements complexity: 0.16 %
#
#  iteration = 3310   edges: 906,   elements: 3266,   edge complexity: 19.87 %,  elements complexity: 0.16 %
#
#  iteration = 3320   edges: 909,   elements: 3276,   edge complexity: 19.93 %,  elements complexity: 0.16 %
#
#  iteration = 3330   edges: 911,   elements: 3286,   edge complexity: 19.98 %,  elements complexity: 0.16 %
#
#  iteration = 3340   edges: 912,   elements: 3296,   edge complexity: 20.0 %,  elements complexity: 0.16 %
#
#  iteration = 3350   edges: 912,   elements: 3306,   edge complexity: 20.0 %,  elements complexity: 0.16 %
#
#  iteration = 3360   edges: 916,   elements: 3316,   edge complexity: 20.09 %,  elements complexity: 0.16 %
#
#  iteration = 3370   edges: 920,   elements: 3326,   edge complexity: 20.18 %,  elements complexity: 0.17 %
#
#  iteration = 3380   edges: 921,   elements: 3335,   edge complexity: 20.2 %,  elements complexity: 0.17 %
#
#  iteration = 3390   edges: 923,   elements: 3345,   edge complexity: 20.24 %,  elements complexity: 0.17 %
#
#  iteration = 3400   edges: 924,   elements: 3355,   edge complexity: 20.26 %,  elements complexity: 0.17 %
#
#  iteration = 3410   edges: 927,   elements: 3365,   edge complexity: 20.33 %,  elements complexity: 0.17 %
#
#  iteration = 3420   edges: 929,   elements: 3375,   edge complexity: 20.37 %,  elements complexity: 0.17 %
#
#  iteration = 3430   edges: 933,   elements: 3385,   edge complexity: 20.46 %,  elements complexity: 0.17 %
#
#  iteration = 3440   edges: 935,   elements: 3395,   edge complexity: 20.5 %,  elements complexity: 0.17 %
#
#  iteration = 3450   edges: 937,   elements: 3405,   edge complexity: 20.55 %,  elements complexity: 0.17 %
#
#  iteration = 3460   edges: 939,   elements: 3415,   edge complexity: 20.59 %,  elements complexity: 0.17 %
#
#  iteration = 3470   edges: 943,   elements: 3425,   edge complexity: 20.68 %,  elements complexity: 0.17 %
#
#  iteration = 3480   edges: 947,   elements: 3435,   edge complexity: 20.77 %,  elements complexity: 0.17 %
#
#  iteration = 3490   edges: 948,   elements: 3445,   edge complexity: 20.79 %,  elements complexity: 0.17 %
#
#  iteration = 3500   edges: 948,   elements: 3455,   edge complexity: 20.79 %,  elements complexity: 0.17 %
#
#  iteration = 3510   edges: 949,   elements: 3465,   edge complexity: 20.81 %,  elements complexity: 0.17 %
#
#  iteration = 3520   edges: 953,   elements: 3475,   edge complexity: 20.9 %,  elements complexity: 0.17 %
#
#  iteration = 3530   edges: 954,   elements: 3485,   edge complexity: 20.92 %,  elements complexity: 0.17 %
#
#  iteration = 3540   edges: 956,   elements: 3494,   edge complexity: 20.96 %,  elements complexity: 0.17 %
#
#  iteration = 3550   edges: 957,   elements: 3504,   edge complexity: 20.99 %,  elements complexity: 0.17 %
#
#  iteration = 3560   edges: 959,   elements: 3513,   edge complexity: 21.03 %,  elements complexity: 0.17 %
#
#  iteration = 3570   edges: 959,   elements: 3523,   edge complexity: 21.03 %,  elements complexity: 0.18 %
#
#  iteration = 3580   edges: 961,   elements: 3532,   edge complexity: 21.07 %,  elements complexity: 0.18 %
#
#  iteration = 3590   edges: 963,   elements: 3541,   edge complexity: 21.12 %,  elements complexity: 0.18 %
#
#  iteration = 3600   edges: 964,   elements: 3551,   edge complexity: 21.14 %,  elements complexity: 0.18 %
#
#  iteration = 3610   edges: 965,   elements: 3561,   edge complexity: 21.16 %,  elements complexity: 0.18 %
#
#  iteration = 3620   edges: 966,   elements: 3571,   edge complexity: 21.18 %,  elements complexity: 0.18 %
#
#  iteration = 3630   edges: 968,   elements: 3581,   edge complexity: 21.23 %,  elements complexity: 0.18 %
#
#  iteration = 3640   edges: 971,   elements: 3591,   edge complexity: 21.29 %,  elements complexity: 0.18 %
#
#  iteration = 3650   edges: 974,   elements: 3600,   edge complexity: 21.36 %,  elements complexity: 0.18 %
#
#  iteration = 3660   edges: 975,   elements: 3610,   edge complexity: 21.38 %,  elements complexity: 0.18 %
#
#  iteration = 3670   edges: 976,   elements: 3620,   edge complexity: 21.4 %,  elements complexity: 0.18 %
#
#  iteration = 3680   edges: 977,   elements: 3630,   edge complexity: 21.43 %,  elements complexity: 0.18 %
#
#  iteration = 3690   edges: 978,   elements: 3640,   edge complexity: 21.45 %,  elements complexity: 0.18 %
#
#  iteration = 3700   edges: 981,   elements: 3650,   edge complexity: 21.51 %,  elements complexity: 0.18 %
#
#  iteration = 3710   edges: 983,   elements: 3660,   edge complexity: 21.56 %,  elements complexity: 0.18 %
#
#  iteration = 3720   edges: 985,   elements: 3670,   edge complexity: 21.6 %,  elements complexity: 0.18 %
#
#  iteration = 3730   edges: 988,   elements: 3680,   edge complexity: 21.67 %,  elements complexity: 0.18 %
#
#  iteration = 3740   edges: 990,   elements: 3690,   edge complexity: 21.71 %,  elements complexity: 0.18 %
#
#  iteration = 3750   edges: 991,   elements: 3699,   edge complexity: 21.73 %,  elements complexity: 0.18 %
#
#  iteration = 3760   edges: 993,   elements: 3709,   edge complexity: 21.78 %,  elements complexity: 0.18 %
#
#  iteration = 3770   edges: 996,   elements: 3718,   edge complexity: 21.84 %,  elements complexity: 0.18 %
#
#  iteration = 3780   edges: 997,   elements: 3726,   edge complexity: 21.86 %,  elements complexity: 0.19 %
#
#  iteration = 3790   edges: 1000,   elements: 3736,   edge complexity: 21.93 %,  elements complexity: 0.19 %
#
#  iteration = 3800   edges: 1004,   elements: 3746,   edge complexity: 22.02 %,  elements complexity: 0.19 %
#
#  iteration = 3810   edges: 1008,   elements: 3756,   edge complexity: 22.11 %,  elements complexity: 0.19 %
#
#  iteration = 3820   edges: 1008,   elements: 3766,   edge complexity: 22.11 %,  elements complexity: 0.19 %
#
#  iteration = 3830   edges: 1008,   elements: 3776,   edge complexity: 22.11 %,  elements complexity: 0.19 %
#
#  iteration = 3840   edges: 1012,   elements: 3786,   edge complexity: 22.19 %,  elements complexity: 0.19 %
#
#  iteration = 3850   edges: 1014,   elements: 3796,   edge complexity: 22.24 %,  elements complexity: 0.19 %
#
#  iteration = 3860   edges: 1020,   elements: 3806,   edge complexity: 22.37 %,  elements complexity: 0.19 %
#
#  iteration = 3870   edges: 1021,   elements: 3815,   edge complexity: 22.39 %,  elements complexity: 0.19 %
#
#  iteration = 3880   edges: 1021,   elements: 3825,   edge complexity: 22.39 %,  elements complexity: 0.19 %
#
#  iteration = 3890   edges: 1022,   elements: 3835,   edge complexity: 22.41 %,  elements complexity: 0.19 %
#
#  iteration = 3900   edges: 1022,   elements: 3845,   edge complexity: 22.41 %,  elements complexity: 0.19 %
#
#  iteration = 3910   edges: 1025,   elements: 3855,   edge complexity: 22.48 %,  elements complexity: 0.19 %
#
#  iteration = 3920   edges: 1026,   elements: 3865,   edge complexity: 22.5 %,  elements complexity: 0.19 %
#
#  iteration = 3930   edges: 1031,   elements: 3874,   edge complexity: 22.61 %,  elements complexity: 0.19 %
#
#  iteration = 3940   edges: 1032,   elements: 3884,   edge complexity: 22.63 %,  elements complexity: 0.19 %
#
#  iteration = 3950   edges: 1032,   elements: 3894,   edge complexity: 22.63 %,  elements complexity: 0.19 %
#
#  iteration = 3960   edges: 1034,   elements: 3904,   edge complexity: 22.68 %,  elements complexity: 0.19 %
#
#  iteration = 3970   edges: 1037,   elements: 3914,   edge complexity: 22.74 %,  elements complexity: 0.19 %
#
#  iteration = 3980   edges: 1038,   elements: 3924,   edge complexity: 22.76 %,  elements complexity: 0.2 %
#
#  iteration = 3990   edges: 1040,   elements: 3934,   edge complexity: 22.81 %,  elements complexity: 0.2 %
#
#  iteration = 4000   edges: 1041,   elements: 3944,   edge complexity: 22.83 %,  elements complexity: 0.2 %
#
#  iteration = 4010   edges: 1043,   elements: 3954,   edge complexity: 22.87 %,  elements complexity: 0.2 %
#
#  iteration = 4020   edges: 1046,   elements: 3963,   edge complexity: 22.94 %,  elements complexity: 0.2 %
#
#  iteration = 4030   edges: 1046,   elements: 3972,   edge complexity: 22.94 %,  elements complexity: 0.2 %
#
#  iteration = 4040   edges: 1047,   elements: 3982,   edge complexity: 22.96 %,  elements complexity: 0.2 %
#
#  iteration = 4050   edges: 1048,   elements: 3992,   edge complexity: 22.98 %,  elements complexity: 0.2 %
#
#  iteration = 4060   edges: 1049,   elements: 4002,   edge complexity: 23.0 %,  elements complexity: 0.2 %
#
#  iteration = 4070   edges: 1049,   elements: 4012,   edge complexity: 23.0 %,  elements complexity: 0.2 %
#
#  iteration = 4080   edges: 1050,   elements: 4022,   edge complexity: 23.03 %,  elements complexity: 0.2 %
#
#  iteration = 4090   edges: 1053,   elements: 4032,   edge complexity: 23.09 %,  elements complexity: 0.2 %
#
#  iteration = 4100   edges: 1054,   elements: 4042,   edge complexity: 23.11 %,  elements complexity: 0.2 %
#
#  iteration = 4110   edges: 1055,   elements: 4051,   edge complexity: 23.14 %,  elements complexity: 0.2 %
#
#  iteration = 4120   edges: 1055,   elements: 4061,   edge complexity: 23.14 %,  elements complexity: 0.2 %
#
#  iteration = 4130   edges: 1056,   elements: 4069,   edge complexity: 23.16 %,  elements complexity: 0.2 %
#
#  iteration = 4140   edges: 1060,   elements: 4079,   edge complexity: 23.25 %,  elements complexity: 0.2 %
#
#  iteration = 4150   edges: 1060,   elements: 4089,   edge complexity: 23.25 %,  elements complexity: 0.2 %
#
#  iteration = 4160   edges: 1062,   elements: 4099,   edge complexity: 23.29 %,  elements complexity: 0.2 %
#
#  iteration = 4170   edges: 1064,   elements: 4108,   edge complexity: 23.33 %,  elements complexity: 0.2 %
#
#  iteration = 4180   edges: 1066,   elements: 4118,   edge complexity: 23.38 %,  elements complexity: 0.2 %
#
#  iteration = 4190   edges: 1067,   elements: 4128,   edge complexity: 23.4 %,  elements complexity: 0.21 %
#
#  iteration = 4200   edges: 1070,   elements: 4138,   edge complexity: 23.46 %,  elements complexity: 0.21 %
#
#  iteration = 4210   edges: 1072,   elements: 4148,   edge complexity: 23.51 %,  elements complexity: 0.21 %
#
#  iteration = 4220   edges: 1073,   elements: 4158,   edge complexity: 23.53 %,  elements complexity: 0.21 %
#
#  iteration = 4230   edges: 1077,   elements: 4168,   edge complexity: 23.62 %,  elements complexity: 0.21 %
#
#  iteration = 4240   edges: 1078,   elements: 4178,   edge complexity: 23.64 %,  elements complexity: 0.21 %
#
#  iteration = 4250   edges: 1081,   elements: 4188,   edge complexity: 23.71 %,  elements complexity: 0.21 %
#
#  iteration = 4260   edges: 1081,   elements: 4198,   edge complexity: 23.71 %,  elements complexity: 0.21 %
#
#  iteration = 4270   edges: 1083,   elements: 4208,   edge complexity: 23.75 %,  elements complexity: 0.21 %
#
#  iteration = 4280   edges: 1084,   elements: 4218,   edge complexity: 23.77 %,  elements complexity: 0.21 %
#
#  iteration = 4290   edges: 1085,   elements: 4226,   edge complexity: 23.79 %,  elements complexity: 0.21 %
#
#  iteration = 4300   edges: 1086,   elements: 4236,   edge complexity: 23.82 %,  elements complexity: 0.21 %
#
#  iteration = 4310   edges: 1086,   elements: 4246,   edge complexity: 23.82 %,  elements complexity: 0.21 %
#
#  iteration = 4320   edges: 1087,   elements: 4255,   edge complexity: 23.84 %,  elements complexity: 0.21 %
#
#  iteration = 4330   edges: 1088,   elements: 4265,   edge complexity: 23.86 %,  elements complexity: 0.21 %
#
#  iteration = 4340   edges: 1089,   elements: 4274,   edge complexity: 23.88 %,  elements complexity: 0.21 %
#
#  iteration = 4350   edges: 1090,   elements: 4283,   edge complexity: 23.9 %,  elements complexity: 0.21 %
#
#  iteration = 4360   edges: 1090,   elements: 4293,   edge complexity: 23.9 %,  elements complexity: 0.21 %
#
#  iteration = 4370   edges: 1092,   elements: 4303,   edge complexity: 23.95 %,  elements complexity: 0.21 %
#
#  iteration = 4380   edges: 1095,   elements: 4313,   edge complexity: 24.01 %,  elements complexity: 0.21 %
#
#  iteration = 4390   edges: 1096,   elements: 4323,   edge complexity: 24.04 %,  elements complexity: 0.21 %
#
#  iteration = 4400   edges: 1097,   elements: 4333,   edge complexity: 24.06 %,  elements complexity: 0.22 %
#
#  iteration = 4410   edges: 1098,   elements: 4342,   edge complexity: 24.08 %,  elements complexity: 0.22 %
#
#  iteration = 4420   edges: 1099,   elements: 4352,   edge complexity: 24.1 %,  elements complexity: 0.22 %
#
#  iteration = 4430   edges: 1101,   elements: 4361,   edge complexity: 24.14 %,  elements complexity: 0.22 %
#
#  iteration = 4440   edges: 1103,   elements: 4371,   edge complexity: 24.19 %,  elements complexity: 0.22 %
#
#  iteration = 4450   edges: 1104,   elements: 4381,   edge complexity: 24.21 %,  elements complexity: 0.22 %
#
#  iteration = 4460   edges: 1107,   elements: 4391,   edge complexity: 24.28 %,  elements complexity: 0.22 %
#
# ...
#
#  iteration = 9750   edges: 1747,   elements: 9581,   edge complexity: 38.31 %,  elements complexity: 0.48 %
#
#  iteration = 9760   edges: 1748,   elements: 9591,   edge complexity: 38.33 %,  elements complexity: 0.48 %
#
#  iteration = 9770   edges: 1750,   elements: 9600,   edge complexity: 38.38 %,  elements complexity: 0.48 %
#
#  iteration = 9780   edges: 1752,   elements: 9608,   edge complexity: 38.42 %,  elements complexity: 0.48 %
#
#  iteration = 9790   edges: 1754,   elements: 9618,   edge complexity: 38.46 %,  elements complexity: 0.48 %
#
#  iteration = 9800   edges: 1756,   elements: 9628,   edge complexity: 38.51 %,  elements complexity: 0.48 %
#
#  iteration = 9810   edges: 1756,   elements: 9638,   edge complexity: 38.51 %,  elements complexity: 0.48 %
#
#  iteration = 9820   edges: 1758,   elements: 9648,   edge complexity: 38.55 %,  elements complexity: 0.48 %
#
#  iteration = 9830   edges: 1759,   elements: 9658,   edge complexity: 38.57 %,  elements complexity: 0.48 %
#
#  iteration = 9840   edges: 1761,   elements: 9668,   edge complexity: 38.62 %,  elements complexity: 0.48 %
#
#  iteration = 9850   edges: 1761,   elements: 9678,   edge complexity: 38.62 %,  elements complexity: 0.48 %
#
#  iteration = 9860   edges: 1761,   elements: 9688,   edge complexity: 38.62 %,  elements complexity: 0.48 %
#
#  iteration = 9870   edges: 1762,   elements: 9696,   edge complexity: 38.64 %,  elements complexity: 0.48 %
#
#  iteration = 9880   edges: 1763,   elements: 9706,   edge complexity: 38.66 %,  elements complexity: 0.48 %
#
#  iteration = 9890   edges: 1763,   elements: 9716,   edge complexity: 38.66 %,  elements complexity: 0.48 %
#
#  iteration = 9900   edges: 1764,   elements: 9726,   edge complexity: 38.68 %,  elements complexity: 0.48 %
#
#  iteration = 9910   edges: 1765,   elements: 9736,   edge complexity: 38.71 %,  elements complexity: 0.48 %
#
#  iteration = 9920   edges: 1765,   elements: 9745,   edge complexity: 38.71 %,  elements complexity: 0.48 %
#
#  iteration = 9930   edges: 1766,   elements: 9755,   edge complexity: 38.73 %,  elements complexity: 0.49 %
#
#  iteration = 9940   edges: 1766,   elements: 9765,   edge complexity: 38.73 %,  elements complexity: 0.49 %
#
#  iteration = 9950   edges: 1766,   elements: 9774,   edge complexity: 38.73 %,  elements complexity: 0.49 %
#
#  iteration = 9960   edges: 1767,   elements: 9784,   edge complexity: 38.75 %,  elements complexity: 0.49 %
#
#  iteration = 9970   edges: 1767,   elements: 9794,   edge complexity: 38.75 %,  elements complexity: 0.49 %
#
#  iteration = 9980   edges: 1767,   elements: 9804,   edge complexity: 38.75 %,  elements complexity: 0.49 %
#
#  iteration = 9990   edges: 1768,   elements: 9813,   edge complexity: 38.77 %,  elements complexity: 0.49 %
#
#  iteration = 10000   edges: 1769,   elements: 9822,   edge complexity: 38.79 %,  elements complexity: 0.49 %
#
#  iteration = 10010   edges: 1771,   elements: 9832,   edge complexity: 38.84 %,  elements complexity: 0.49 %
#
#  iteration = 10020   edges: 1772,   elements: 9842,   edge complexity: 38.86 %,  elements complexity: 0.49 %
#
#  iteration = 10030   edges: 1774,   elements: 9852,   edge complexity: 38.9 %,  elements complexity: 0.49 %
#
#  iteration = 10040   edges: 1775,   elements: 9862,   edge complexity: 38.93 %,  elements complexity: 0.49 %
#
#  iteration = 10050   edges: 1775,   elements: 9872,   edge complexity: 38.93 %,  elements complexity: 0.49 %
#
#  iteration = 10060   edges: 1777,   elements: 9882,   edge complexity: 38.97 %,  elements complexity: 0.49 %
#
#  iteration = 10070   edges: 1779,   elements: 9892,   edge complexity: 39.01 %,  elements complexity: 0.49 %
#
#  iteration = 10080   edges: 1779,   elements: 9902,   edge complexity: 39.01 %,  elements complexity: 0.49 %
#
#  iteration = 10090   edges: 1780,   elements: 9912,   edge complexity: 39.04 %,  elements complexity: 0.49 %
#
#  iteration = 10100   edges: 1782,   elements: 9922,   edge complexity: 39.08 %,  elements complexity: 0.49 %
#
#  iteration = 10110   edges: 1786,   elements: 9932,   edge complexity: 39.17 %,  elements complexity: 0.49 %
#
#  iteration = 10120   edges: 1786,   elements: 9942,   edge complexity: 39.17 %,  elements complexity: 0.49 %
#
#  iteration = 10130   edges: 1787,   elements: 9952,   edge complexity: 39.19 %,  elements complexity: 0.49 %
#
#  iteration = 10140   edges: 1787,   elements: 9962,   edge complexity: 39.19 %,  elements complexity: 0.5 %
#
#  iteration = 10150   edges: 1788,   elements: 9972,   edge complexity: 39.21 %,  elements complexity: 0.5 %
#
#  iteration = 10160   edges: 1788,   elements: 9982,   edge complexity: 39.21 %,  elements complexity: 0.5 %
#
#  iteration = 10170   edges: 1789,   elements: 9992,   edge complexity: 39.23 %,  elements complexity: 0.5 %
#
#  iteration = 10180   edges: 1790,   elements: 10002,   edge complexity: 39.25 %,  elements complexity: 0.5 %
#
#  iteration = 10190   edges: 1791,   elements: 10012,   edge complexity: 39.28 %,  elements complexity: 0.5 %
#
#  iteration = 10200   edges: 1791,   elements: 10022,   edge complexity: 39.28 %,  elements complexity: 0.5 %
#
#  iteration = 10210   edges: 1792,   elements: 10032,   edge complexity: 39.3 %,  elements complexity: 0.5 %
#
#  iteration = 10220   edges: 1794,   elements: 10042,   edge complexity: 39.34 %,  elements complexity: 0.5 %
#
#  iteration = 10230   edges: 1796,   elements: 10052,   edge complexity: 39.39 %,  elements complexity: 0.5 %
#
#  iteration = 10240   edges: 1796,   elements: 10061,   edge complexity: 39.39 %,  elements complexity: 0.5 %
#
#  iteration = 10250   edges: 1797,   elements: 10071,   edge complexity: 39.41 %,  elements complexity: 0.5 %
#
#  iteration = 10260   edges: 1798,   elements: 10081,   edge complexity: 39.43 %,  elements complexity: 0.5 %
#
#  iteration = 10270   edges: 1798,   elements: 10091,   edge complexity: 39.43 %,  elements complexity: 0.5 %
#
#  iteration = 10280   edges: 1798,   elements: 10101,   edge complexity: 39.43 %,  elements complexity: 0.5 %
#
#  iteration = 10290   edges: 1798,   elements: 10111,   edge complexity: 39.43 %,  elements complexity: 0.5 %
#
#  iteration = 10300   edges: 1798,   elements: 10120,   edge complexity: 39.43 %,  elements complexity: 0.5 %
#
#  iteration = 10310   edges: 1798,   elements: 10130,   edge complexity: 39.43 %,  elements complexity: 0.5 %
#
#  iteration = 10320   edges: 1798,   elements: 10140,   edge complexity: 39.43 %,  elements complexity: 0.5 %
#
#  iteration = 10330   edges: 1798,   elements: 10150,   edge complexity: 39.43 %,  elements complexity: 0.5 %
#
#  iteration = 10340   edges: 1798,   elements: 10160,   edge complexity: 39.43 %,  elements complexity: 0.51 %
#
#  iteration = 10350   edges: 1798,   elements: 10169,   edge complexity: 39.43 %,  elements complexity: 0.51 %
#
#  iteration = 10360   edges: 1799,   elements: 10178,   edge complexity: 39.45 %,  elements complexity: 0.51 %
#
#  iteration = 10370   edges: 1799,   elements: 10188,   edge complexity: 39.45 %,  elements complexity: 0.51 %
#
#  iteration = 10380   edges: 1799,   elements: 10197,   edge complexity: 39.45 %,  elements complexity: 0.51 %
#
#  iteration = 10390   edges: 1799,   elements: 10207,   edge complexity: 39.45 %,  elements complexity: 0.51 %
#
#  iteration = 10400   edges: 1799,   elements: 10217,   edge complexity: 39.45 %,  elements complexity: 0.51 %
#
#  iteration = 10410   edges: 1800,   elements: 10226,   edge complexity: 39.47 %,  elements complexity: 0.51 %
#
#  iteration = 10420   edges: 1802,   elements: 10236,   edge complexity: 39.52 %,  elements complexity: 0.51 %
#
#  iteration = 10430   edges: 1803,   elements: 10246,   edge complexity: 39.54 %,  elements complexity: 0.51 %
#
#  iteration = 10440   edges: 1805,   elements: 10256,   edge complexity: 39.58 %,  elements complexity: 0.51 %
#
#  iteration = 10450   edges: 1805,   elements: 10265,   edge complexity: 39.58 %,  elements complexity: 0.51 %
#
#  iteration = 10460   edges: 1806,   elements: 10275,   edge complexity: 39.61 %,  elements complexity: 0.51 %
#
#  iteration = 10470   edges: 1806,   elements: 10285,   edge complexity: 39.61 %,  elements complexity: 0.51 %
#
#  iteration = 10480   edges: 1807,   elements: 10295,   edge complexity: 39.63 %,  elements complexity: 0.51 %
#
#  iteration = 10490   edges: 1807,   elements: 10302,   edge complexity: 39.63 %,  elements complexity: 0.51 %
#
#  iteration = 10500   edges: 1808,   elements: 10311,   edge complexity: 39.65 %,  elements complexity: 0.51 %
#
#  iteration = 10510   edges: 1808,   elements: 10321,   edge complexity: 39.65 %,  elements complexity: 0.51 %
#
#  iteration = 10520   edges: 1809,   elements: 10331,   edge complexity: 39.67 %,  elements complexity: 0.51 %
#
#  iteration = 10530   edges: 1812,   elements: 10341,   edge complexity: 39.74 %,  elements complexity: 0.51 %
#
#  iteration = 10540   edges: 1813,   elements: 10351,   edge complexity: 39.76 %,  elements complexity: 0.51 %
#
#  iteration = 10550   edges: 1813,   elements: 10360,   edge complexity: 39.76 %,  elements complexity: 0.52 %
#
#  iteration = 10560   edges: 1814,   elements: 10370,   edge complexity: 39.78 %,  elements complexity: 0.52 %
#
#  iteration = 10570   edges: 1814,   elements: 10380,   edge complexity: 39.78 %,  elements complexity: 0.52 %
#
#  iteration = 10580   edges: 1816,   elements: 10390,   edge complexity: 39.82 %,  elements complexity: 0.52 %
#
#  iteration = 10590   edges: 1819,   elements: 10400,   edge complexity: 39.89 %,  elements complexity: 0.52 %
#
#  iteration = 10600   edges: 1819,   elements: 10410,   edge complexity: 39.89 %,  elements complexity: 0.52 %
#
#  iteration = 10610   edges: 1819,   elements: 10420,   edge complexity: 39.89 %,  elements complexity: 0.52 %
#
#  iteration = 10620   edges: 1822,   elements: 10430,   edge complexity: 39.96 %,  elements complexity: 0.52 %
#
#  iteration = 10630   edges: 1823,   elements: 10440,   edge complexity: 39.98 %,  elements complexity: 0.52 %
#
#  iteration = 10640   edges: 1825,   elements: 10449,   edge complexity: 40.02 %,  elements complexity: 0.52 %
#
#  iteration = 10650   edges: 1827,   elements: 10459,   edge complexity: 40.07 %,  elements complexity: 0.52 %
#
#  iteration = 10660   edges: 1827,   elements: 10469,   edge complexity: 40.07 %,  elements complexity: 0.52 %
#
#  iteration = 10670   edges: 1829,   elements: 10479,   edge complexity: 40.11 %,  elements complexity: 0.52 %
#
#  iteration = 10680   edges: 1829,   elements: 10489,   edge complexity: 40.11 %,  elements complexity: 0.52 %
#
#  iteration = 10690   edges: 1829,   elements: 10498,   edge complexity: 40.11 %,  elements complexity: 0.52 %
#
#  iteration = 10700   edges: 1829,   elements: 10508,   edge complexity: 40.11 %,  elements complexity: 0.52 %
#
#  iteration = 10710   edges: 1831,   elements: 10518,   edge complexity: 40.15 %,  elements complexity: 0.52 %
#
#  iteration = 10720   edges: 1832,   elements: 10528,   edge complexity: 40.18 %,  elements complexity: 0.52 %
#
#  iteration = 10730   edges: 1833,   elements: 10538,   edge complexity: 40.2 %,  elements complexity: 0.52 %
#
#  iteration = 10740   edges: 1833,   elements: 10548,   edge complexity: 40.2 %,  elements complexity: 0.52 %
#
#  iteration = 10750   edges: 1833,   elements: 10557,   edge complexity: 40.2 %,  elements complexity: 0.52 %
#
#  iteration = 10760   edges: 1833,   elements: 10567,   edge complexity: 40.2 %,  elements complexity: 0.53 %
#
#  iteration = 10770   edges: 1833,   elements: 10577,   edge complexity: 40.2 %,  elements complexity: 0.53 %
#
#  iteration = 10780   edges: 1833,   elements: 10587,   edge complexity: 40.2 %,  elements complexity: 0.53 %
#
#  iteration = 10790   edges: 1833,   elements: 10597,   edge complexity: 40.2 %,  elements complexity: 0.53 %
#
#  iteration = 10800   edges: 1834,   elements: 10607,   edge complexity: 40.22 %,  elements complexity: 0.53 %
#
#  iteration = 10810   edges: 1836,   elements: 10617,   edge complexity: 40.26 %,  elements complexity: 0.53 %
#
#  iteration = 10820   edges: 1836,   elements: 10627,   edge complexity: 40.26 %,  elements complexity: 0.53 %
#
#  iteration = 10830   edges: 1836,   elements: 10637,   edge complexity: 40.26 %,  elements complexity: 0.53 %
#
#  iteration = 10840   edges: 1837,   elements: 10647,   edge complexity: 40.29 %,  elements complexity: 0.53 %
#
#  iteration = 10850   edges: 1837,   elements: 10657,   edge complexity: 40.29 %,  elements complexity: 0.53 %
#
#  iteration = 10860   edges: 1837,   elements: 10666,   edge complexity: 40.29 %,  elements complexity: 0.53 %
#
#  iteration = 10870   edges: 1838,   elements: 10676,   edge complexity: 40.31 %,  elements complexity: 0.53 %
# InterruptException:
#
# Stacktrace:
#   [1] Array
#     @ ./boot.jl:459 [inlined]
#   [2] Array
#     @ ./boot.jl:468 [inlined]
#   [3] Array
#     @ ./boot.jl:476 [inlined]
#   [4] similar
#     @ ./abstractarray.jl:841 [inlined]
#   [5] similar
#     @ ./abstractarray.jl:840 [inlined]
#   [6] similar
#     @ ./broadcast.jl:212 [inlined]
#   [7] similar
#     @ ./broadcast.jl:211 [inlined]
#   [8] copy
#     @ ./broadcast.jl:885 [inlined]
#   [9] materialize
#     @ ./broadcast.jl:860 [inlined]
#  [10] gibbs_sampling(q::Int64, h_local::Vector{Float64}, Jij::Array{Float32, 3}, sequences::Matrix{Int8}, site_degree::Vector{Int64}, contact_list::Matrix{Int64}, sweeps::Int64)
#     @ Main ~/Documents/GitHub/FCSeqTools.jl/Example_Proteins/src/FCSeqTools.jl:168
#  [11] (::var"#32#36"{IOStream, IOStream, IOStream, Int64, Int64, Float64, Int64, String, Float64, Float64, Int64, Vector{Any}, Float32, Vector{Float32}, Array{Float64, 3}, Vector{Float64}, Int64})(f3::IOStream)
#     @ Main ~/Documents/GitHub/FCSeqTools.jl/Example_Proteins/src/FCSeqTools.jl:530
#  [12] open(::var"#32#36"{IOStream, IOStream, IOStream, Int64, Int64, Float64, Int64, String, Float64, Float64, Int64, Vector{Any}, Float32, Vector{Float32}, Array{Float64, 3}, Vector{Float64}, Int64}, ::String, ::Vararg{String}; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Base ./io.jl:384
#  [13] open
#     @ ./io.jl:381 [inlined]
#  [14] (::var"#31#35"{IOStream, IOStream, Int64, Int64, Float64, Int64, String, Float64, Float64, Int64, Vector{Any}, Float32, Vector{Float32}, Array{Float64, 3}, Vector{Float64}, Int64})(f2::IOStream)
#     @ Main ~/Documents/GitHub/FCSeqTools.jl/Example_Proteins/src/FCSeqTools.jl:521
#  [15] open(::var"#31#35"{IOStream, IOStream, Int64, Int64, Float64, Int64, String, Float64, Float64, Int64, Vector{Any}, Float32, Vector{Float32}, Array{Float64, 3}, Vector{Float64}, Int64}, ::String, ::Vararg{String}; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Base ./io.jl:384
#  [16] open
#     @ ./io.jl:381 [inlined]
#  [17] (::var"#30#34"{IOStream, Int64, Int64, Float64, Int64, String, Float64, Float64, Int64, Vector{Any}, Float32, Vector{Float32}, Array{Float64, 3}, Vector{Float64}, Int64})(f1::IOStream)
#     @ Main ~/Documents/GitHub/FCSeqTools.jl/Example_Proteins/src/FCSeqTools.jl:520
#  [18] open(::var"#30#34"{IOStream, Int64, Int64, Float64, Int64, String, Float64, Float64, Int64, Vector{Any}, Float32, Vector{Float32}, Array{Float64, 3}, Vector{Float64}, Int64}, ::String, ::Vararg{String}; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Base ./io.jl:384
#  [19] open
#     @ ./io.jl:381 [inlined]
#  [20] (::var"#29#33"{Int64, Int64, Float64, Int64, String, Float64, Float64, Int64, Vector{Any}, Float32, Vector{Float32}, Array{Float64, 3}, Vector{Float64}, Int64})(f::IOStream)
#     @ Main ~/Documents/GitHub/FCSeqTools.jl/Example_Proteins/src/FCSeqTools.jl:519
#  [21] open(::var"#29#33"{Int64, Int64, Float64, Int64, String, Float64, Float64, Int64, Vector{Any}, Float32, Vector{Float32}, Array{Float64, 3}, Vector{Float64}, Int64}, ::String, ::Vararg{String}; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Base ./io.jl:384
#  [22] open
#     @ ./io.jl:381 [inlined]
#  [23] E_A_A(q::Int64, n_step::Int64, pseudo_count::Float64, number::Int64, number_matrix::Matrix{Int8}, filename::String, family_name::String, test_folder::String, method::String, notebook::String, fraction::Float64, stop::Float64)
#     @ Main ~/Documents/GitHub/FCSeqTools.jl/Example_Proteins/src/FCSeqTools.jl:518

# %% [markdown]
# ## saving data

# %%
using JLD

init_pseudo_count = 0.01
folder_name = "../training/" * method * string(fraction) * "_stop=" * string(stop) * "_reg="*string(pseudo_count)*"_h_ps-count=" * string(init_pseudo_count) * "nbook="*notebook

JLD.save(folder_name*"/"*"score.jld","data", score)
JLD.save(folder_name*"/"*"likelihood_gain.jld","data", likelihood_gain)
JLD.save(folder_name*"/"*"generated_sequences.jld","data", generated_sequences)
JLD.save(folder_name*"/"*"Jij.jld","data", Jij)
JLD.save(folder_name*"/"*"h.jld","data", h)
JLD.save(folder_name*"/"*"contact_list.jld","data", contact_list)
JLD.save(folder_name*"/"*"site_degree.jld","data", site_degree)
JLD.save(folder_name*"/"*"edge_list.jld","data", edge_list)

# %% [markdown]
# ## Saving the model

# %%
function print_model_to_file_prot(natural_sequences,Jij,h,filename)
    open(filename, "w") do f
        for i in 1:length(natural_sequences[1,:])
            for j in i+1:length(natural_sequences[1,:])
                for k in 1:21    
                    if k==1
                        k2=1        
                    elseif k==2
                        k2=2
                    elseif k==3
                        k2=3
                    elseif k==4
                        k2=4
                    elseif k==5
                        k2=5
                    elseif k==6
                        k2=6
                    elseif k==7
                        k2=7
                    elseif k==8
                        k2=8
                    elseif k==9
                        k2=9
                    elseif k==10
                        k2=10
                    elseif k==11
                        k2=11
                    elseif k==12
                        k2=12
                    elseif k==13
                        k2=13
                    elseif k==14
                        k2=14
                    elseif k==15
                        k2=15
                    elseif k==16
                        k2=16
                    elseif k==17
                        k2=17
                    elseif k==18
                        k2=18
                    elseif k==19
                        k2=19
                    elseif k==20
                        k2=20
                    elseif k==21
                        k2=0
                    end
                        
                    for l in 1:21
                        if l==1
                            l2=1
                        elseif l==2
                            l2=2
                        elseif l==3
                            l2=3
                        elseif l==4
                            l2=4
                        elseif l==5
                            l2=5
                        elseif l==6
                            l2=6
                        elseif l==7
                            l2=7
                        elseif l==8
                            l2=8
                        elseif l==9
                            l2=9
                        elseif l==10
                            l2=10
                        elseif l==11
                            l2=11
                        elseif l==12
                            l2=12
                        elseif l==13
                            l2=13
                        elseif l==14
                            l2=14
                        elseif l==15
                            l2=15
                        elseif l==16
                            l2=16
                        elseif l==17
                            l2=17
                        elseif l==18
                            l2=18
                        elseif l==19
                            l2=19
                        elseif l==20
                            l2=20
                        elseif l==21
                            l2=0
                        end
                        opo=Jij[i,j,21*(k-1)+l]
                        write(f,"\nJ $(i-1) $(j-1) $(k2) $(l2) $opo" )
                    end
                end
            end
        end
        for i in 1:length(natural_sequences[1,:])
            for j in 1:21          
                if j==1
                    j2=1
                elseif j==2
                    j2=2
                elseif j==3
                    j2=3
                elseif j==4
                    j2=4
                elseif j==5
                    j2=5
                elseif j==6
                    j2=6
                elseif j==7
                    j2=7
                elseif j==8
                    j2=8
                elseif j==9
                    j2=9
                elseif j==10
                    j2=10
                elseif j==11
                    j2=11
                elseif j==12
                    j2=12
                elseif j==13
                    j2=13
                elseif j==14
                    j2=14
                elseif j==15
                    j2=15
                elseif j==16
                    j2=16
                elseif j==17
                    j2=17
                elseif j==18
                    j2=18
                elseif j==19
                    j2=19
                elseif j==20
                    j2=20
                elseif j==21
                    j2=0
                end
                opo=h[21*(i-1)+j]
                write(f,"\nh $(i-1) $(j2) $opo" )
            end
        end
    end
end
# Out:
# print_model_to_file_prot (generic function with 1 method)

# %%
filename = "../saved_models/model_cumulative0.3_pseudocount0.5_init_pscount0.01_nbook_test1.txt"
print_model_to_file_prot(natural_sequences, Jij, h, filename)

# %% [markdown]
# <font size="3">The model obtained has a performance comparable to the fully connected DCA while having just ~20% of its connectivity. The entropy of the model is 35.08. This means that it is able to generate e³⁵ (3.5x10¹⁵) different 55-102 segments for the RF00379 family. \
# Now we can test our artificial sequences. We do the classical statistical check of the PCA projection and the two-point correlation representation. \
# We test the performance of our model against the one of the Covariance Model. The CM model only contains trivial one-point and secondary information so our model must do better than it. </font>

# %%
cm_sequences = rna_cm_model_generation(0.8,0.05,7000,natural_sequences,ss_contact_matrix);

# %%
plot_stat_check(natural_sequences, generated_sequences, cm_sequences)

# %% [markdown]
# <font size="3">The E.A.A. artificial molecules are practically statistically indistinguishable from the natural ones. We see that they have a very similar PCA projection (artificial one seems richer just because we have more artificial sequences than natural ones) while Covariance Model fails to capture the details of the distribution.
#     The selected model has almost a perfect two-point statistics for all site pairs while the CM model only captures it for the ones involved in secondary structure contacts. \
#      </font>

# %% [markdown]
# <font size="3">The interpretability is one of the main reasons in our quest to find parsimonious generative models. Now that we are sure we obtained a good generative model with relatively few parameters we can try to interprete them. \
# Dividing the added edges in secondary structure contacts, 3D contacts we have:

# %%
edge_interpretation_plot(len,ss_contact_matrix,tertiary_contact_matrix,edge_list[1:50,:])

# %% [markdown]
# <font size="3">We see that the secondary structure contacts are taken in the first few iteration. We have lot of neighbouring sites probably due to philogenic effects. It is striking that we see some 3D contacts (in particular around site 40) before the NONE edges. This
# suggests that our algorithm effectively captures some information about the tertiary structure. \
# Those results, that are far more general than this simple example, suggest that the added edges have a co-evolutionary interpretation.

# %% [markdown]
# <font size="3">
# This notebook serves as an example of the application of the techniques described in the main text.
