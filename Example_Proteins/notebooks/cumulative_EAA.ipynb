# %% [markdown]
# # Edge Addition Algorithm - simple implementation example

# %% [markdown]
# <font size="3">Run time is around ~5 minutes with the default input. \
# \
# In this example we will use the E.A.A. model to build a low-connectivity DCA model. \
# The information that we have about the training RNA family consists in: the sequence alignment and the consenus secondary structure (both trough the Covariance Model) and the 3D contacts trough the PDB file. </font>

# %%
include("../src/FCSeqTools.jl");

# %% [markdown]
# <font size="3">Here is an example of  RF00379 molecule and its associated consensus secondary structure. \
# To make the execution faster we will not generate full lenght molecules but just a portion from nucleotide 55 to 102. </font>

# %%
natural_sequences = do_number_matrix_prot(do_letter_matrix("../data/CM_130530_MC.fasta"), 0.2);

# %% [markdown]
# <font size="3">Here is a segment example with its associated secondary structure. \
# The database has a different size because the data-cleaning procedure depends on the region selected. \
# Now we will run the E.A.A. building up our ineraction netwotk edge by edge till we reach a good performance generative model. \
# At each iteration the algorithm reports: the added edge, the iteration number, the number of total added edges and the connectivity percentace of the fully connected case.\
# Each 15 iterations the algorithm reports: the model score (Pearson between natural and artificial two-point correlations), the model mean energy, the model partition function and the model entropy.

# %%
using Random

n_step = 100_000
method = "cumulative"
fraction = 0.3
stop = 0.9
pseudo_count = 0.5
s = time()
Random.seed!(2) 
notebook = "test"
                                                                                                                                                           
score, likelihood_gain, generated_sequences, Jij, h, contact_list, site_degree, edge_list, path = E_A_A(21, n_step, pseudo_count, 12000, natural_sequences,"example_output.txt", method, notebook, fraction, stop); 
s = time() - s
# Out:
# Fully connected model has 4560 edges, 2010960 elements and a score around ~ 0.95
#
# iteration = 20,   Score = 0.1
#
#  <E> = 195.94,  log(Z) = -0.43,   S = 195.5
#  edges: 20,   elements: 75,   edge complexity: 0.44 %,  elements complexity: 0.0 %
#
# iteration = 40,   Score = 0.156
#
#  <E> = 193.98,  log(Z) = -0.63,   S = 193.35
#  edges: 40,   elements: 177,   edge complexity: 0.88 %,  elements complexity: 0.01 %
#
# iteration = 60,   Score = 0.213
#
#  <E> = 190.67,  log(Z) = -1.16,   S = 189.51
#  edges: 60,   elements: 290,   edge complexity: 1.32 %,  elements complexity: 0.01 %
#
# iteration = 80,   Score = 0.261
#
#  <E> = 189.36,  log(Z) = -1.09,   S = 188.27
#  edges: 79,   elements: 388,   edge complexity: 1.73 %,  elements complexity: 0.02 %
#
# iteration = 100,   Score = 0.314
#
#  <E> = 186.86,  log(Z) = -1.4,   S = 185.46
#  edges: 98,   elements: 510,   edge complexity: 2.15 %,  elements complexity: 0.03 %
#
# iteration = 120,   Score = 0.343
#
#  <E> = 185.0,  log(Z) = -1.73,   S = 183.27
#  edges: 116,   elements: 664,   edge complexity: 2.54 %,  elements complexity: 0.03 %
#
# iteration = 140,   Score = 0.381
#
#  <E> = 183.69,  log(Z) = -1.74,   S = 181.95
#  edges: 135,   elements: 769,   edge complexity: 2.96 %,  elements complexity: 0.04 %
#
# iteration = 160,   Score = 0.418
#
#  <E> = 181.53,  log(Z) = -1.87,   S = 179.66
#  edges: 154,   elements: 875,   edge complexity: 3.38 %,  elements complexity: 0.04 %
#
# iteration = 180,   Score = 0.45
#
#  <E> = 178.07,  log(Z) = -1.9,   S = 176.18
#  edges: 172,   elements: 997,   edge complexity: 3.77 %,  elements complexity: 0.05 %
#
# iteration = 200,   Score = 0.474
#
#  <E> = 175.62,  log(Z) = -2.14,   S = 173.48
#  edges: 189,   elements: 1120,   edge complexity: 4.14 %,  elements complexity: 0.06 %
#
# iteration = 220,   Score = 0.498
#
#  <E> = 174.55,  log(Z) = -2.32,   S = 172.23
#  edges: 206,   elements: 1266,   edge complexity: 4.52 %,  elements complexity: 0.06 %
#
# iteration = 240,   Score = 0.518
#
#  <E> = 173.16,  log(Z) = -2.39,   S = 170.76
#  edges: 225,   elements: 1381,   edge complexity: 4.93 %,  elements complexity: 0.07 %
#
# iteration = 260,   Score = 0.544
#
#  <E> = 171.89,  log(Z) = -2.45,   S = 169.44
#  edges: 241,   elements: 1514,   edge complexity: 5.29 %,  elements complexity: 0.08 %
#
# iteration = 280,   Score = 0.561
#
#  <E> = 170.32,  log(Z) = -2.47,   S = 167.86
#  edges: 260,   elements: 1654,   edge complexity: 5.7 %,  elements complexity: 0.08 %
#
# iteration = 300,   Score = 0.585
#
#  <E> = 168.78,  log(Z) = -2.46,   S = 166.32
#  edges: 279,   elements: 1804,   edge complexity: 6.12 %,  elements complexity: 0.09 %
#
# iteration = 320,   Score = 0.601
#
#  <E> = 167.17,  log(Z) = -2.56,   S = 164.62
#  edges: 298,   elements: 1955,   edge complexity: 6.54 %,  elements complexity: 0.1 %
#
# iteration = 340,   Score = 0.622
#
#  <E> = 166.09,  log(Z) = -2.66,   S = 163.43
#  edges: 315,   elements: 2104,   edge complexity: 6.91 %,  elements complexity: 0.1 %
#
# iteration = 360,   Score = 0.633
#
#  <E> = 164.3,  log(Z) = -2.64,   S = 161.66
#  edges: 333,   elements: 2263,   edge complexity: 7.3 %,  elements complexity: 0.11 %
#
# iteration = 380,   Score = 0.649
#
#  <E> = 162.62,  log(Z) = -2.62,   S = 160.0
#  edges: 352,   elements: 2404,   edge complexity: 7.72 %,  elements complexity: 0.12 %
#
# iteration = 400,   Score = 0.662
#
#  <E> = 161.17,  log(Z) = -2.65,   S = 158.52
#  edges: 368,   elements: 2582,   edge complexity: 8.07 %,  elements complexity: 0.13 %
#
# iteration = 420,   Score = 0.676
#
#  <E> = 159.73,  log(Z) = -2.67,   S = 157.06
#  edges: 387,   elements: 2725,   edge complexity: 8.49 %,  elements complexity: 0.14 %
#
# iteration = 440,   Score = 0.687
#
#  <E> = 157.95,  log(Z) = -2.67,   S = 155.28
#  edges: 403,   elements: 2922,   edge complexity: 8.84 %,  elements complexity: 0.15 %
#
# iteration = 460,   Score = 0.694
#
#  <E> = 158.11,  log(Z) = -2.74,   S = 155.37
#  edges: 422,   elements: 3099,   edge complexity: 9.25 %,  elements complexity: 0.15 %
#
# iteration = 480,   Score = 0.702
#
#  <E> = 156.62,  log(Z) = -2.77,   S = 153.86
#  edges: 439,   elements: 3280,   edge complexity: 9.63 %,  elements complexity: 0.16 %
#
# iteration = 500,   Score = 0.711
#
#  <E> = 156.48,  log(Z) = -2.73,   S = 153.74
#  edges: 457,   elements: 3458,   edge complexity: 10.02 %,  elements complexity: 0.17 %
#
# iteration = 520,   Score = 0.721
#
#  <E> = 154.43,  log(Z) = -2.56,   S = 151.87
#  edges: 475,   elements: 3657,   edge complexity: 10.42 %,  elements complexity: 0.18 %
#
# iteration = 540,   Score = 0.725
#
#  <E> = 153.94,  log(Z) = -2.49,   S = 151.44
#  edges: 491,   elements: 3851,   edge complexity: 10.77 %,  elements complexity: 0.19 %
#
# iteration = 560,   Score = 0.73
#
#  <E> = 152.39,  log(Z) = -2.41,   S = 149.98
#  edges: 505,   elements: 4059,   edge complexity: 11.07 %,  elements complexity: 0.2 %
#
# iteration = 580,   Score = 0.738
#
#  <E> = 150.29,  log(Z) = -2.26,   S = 148.03
#  edges: 521,   elements: 4248,   edge complexity: 11.43 %,  elements complexity: 0.21 %
#
# iteration = 600,   Score = 0.744
#
#  <E> = 149.83,  log(Z) = -2.14,   S = 147.69
#  edges: 539,   elements: 4458,   edge complexity: 11.82 %,  elements complexity: 0.22 %
#
# iteration = 620,   Score = 0.754
#
#  <E> = 147.99,  log(Z) = -2.03,   S = 145.96
#  edges: 554,   elements: 4641,   edge complexity: 12.15 %,  elements complexity: 0.23 %
#
# iteration = 640,   Score = 0.76
#
#  <E> = 147.25,  log(Z) = -2.0,   S = 145.25
#  edges: 571,   elements: 4849,   edge complexity: 12.52 %,  elements complexity: 0.24 %
#
# iteration = 660,   Score = 0.763
#
#  <E> = 145.94,  log(Z) = -1.8,   S = 144.14
#  edges: 585,   elements: 5066,   edge complexity: 12.83 %,  elements complexity: 0.25 %
#
# iteration = 680,   Score = 0.773
#
#  <E> = 144.59,  log(Z) = -1.63,   S = 142.95
#  edges: 605,   elements: 5234,   edge complexity: 13.27 %,  elements complexity: 0.26 %
#
# iteration = 700,   Score = 0.778
#
#  <E> = 143.3,  log(Z) = -1.42,   S = 141.87
#  edges: 619,   elements: 5420,   edge complexity: 13.57 %,  elements complexity: 0.27 %
#
# iteration = 720,   Score = 0.785
#
#  <E> = 142.34,  log(Z) = -1.34,   S = 141.01
#  edges: 634,   elements: 5614,   edge complexity: 13.9 %,  elements complexity: 0.28 %
#
# iteration = 740,   Score = 0.789
#
#  <E> = 141.14,  log(Z) = -1.12,   S = 140.03
#  edges: 649,   elements: 5811,   edge complexity: 14.23 %,  elements complexity: 0.29 %
#
# iteration = 760,   Score = 0.79
#
#  <E> = 140.64,  log(Z) = -1.04,   S = 139.6
#  edges: 661,   elements: 6012,   edge complexity: 14.5 %,  elements complexity: 0.3 %
#
# iteration = 780,   Score = 0.795
#
#  <E> = 139.36,  log(Z) = -0.9,   S = 138.46
#  edges: 679,   elements: 6214,   edge complexity: 14.89 %,  elements complexity: 0.31 %
#
# iteration = 800,   Score = 0.798
#
#  <E> = 138.7,  log(Z) = -0.8,   S = 137.91
#  edges: 697,   elements: 6443,   edge complexity: 15.29 %,  elements complexity: 0.32 %
#
# iteration = 820,   Score = 0.804
#
#  <E> = 137.36,  log(Z) = -0.71,   S = 136.65
#  edges: 707,   elements: 6648,   edge complexity: 15.5 %,  elements complexity: 0.33 %
#
# iteration = 840,   Score = 0.805
#
#  <E> = 136.95,  log(Z) = -0.62,   S = 136.33
#  edges: 719,   elements: 6857,   edge complexity: 15.77 %,  elements complexity: 0.34 %
#
# iteration = 860,   Score = 0.807
#
#  <E> = 136.28,  log(Z) = -0.48,   S = 135.8
#  edges: 733,   elements: 7086,   edge complexity: 16.07 %,  elements complexity: 0.35 %
#
# iteration = 880,   Score = 0.808
#
#  <E> = 135.42,  log(Z) = -0.39,   S = 135.03
#  edges: 749,   elements: 7303,   edge complexity: 16.43 %,  elements complexity: 0.36 %
#
# iteration = 900,   Score = 0.811
#
#  <E> = 134.74,  log(Z) = -0.18,   S = 134.56
#  edges: 763,   elements: 7507,   edge complexity: 16.73 %,  elements complexity: 0.37 %
#
# iteration = 920,   Score = 0.813
#
#  <E> = 133.74,  log(Z) = 0.04,   S = 133.78
#  edges: 779,   elements: 7743,   edge complexity: 17.08 %,  elements complexity: 0.39 %
#
# iteration = 940,   Score = 0.819
#
#  <E> = 132.79,  log(Z) = 0.2,   S = 132.98
#  edges: 796,   elements: 7937,   edge complexity: 17.46 %,  elements complexity: 0.39 %
#
# iteration = 960,   Score = 0.821
#
#  <E> = 131.64,  log(Z) = 0.35,   S = 131.99
#  edges: 812,   elements: 8178,   edge complexity: 17.81 %,  elements complexity: 0.41 %
#
# iteration = 980,   Score = 0.823
#
#  <E> = 130.86,  log(Z) = 0.51,   S = 131.37
#  edges: 826,   elements: 8407,   edge complexity: 18.11 %,  elements complexity: 0.42 %
#
# iteration = 1000,   Score = 0.824
#
#  <E> = 130.72,  log(Z) = 0.69,   S = 131.41
#  edges: 840,   elements: 8632,   edge complexity: 18.42 %,  elements complexity: 0.43 %
#
# iteration = 1020,   Score = 0.829
#
#  <E> = 130.28,  log(Z) = 0.87,   S = 131.15
#  edges: 857,   elements: 8821,   edge complexity: 18.79 %,  elements complexity: 0.44 %
#
# iteration = 1040,   Score = 0.832
#
#  <E> = 129.66,  log(Z) = 1.08,   S = 130.74
#  edges: 871,   elements: 9077,   edge complexity: 19.1 %,  elements complexity: 0.45 %
#
# iteration = 1060,   Score = 0.831
#
#  <E> = 128.51,  log(Z) = 1.23,   S = 129.74
#  edges: 884,   elements: 9300,   edge complexity: 19.39 %,  elements complexity: 0.46 %
#
# iteration = 1080,   Score = 0.834
#
#  <E> = 128.05,  log(Z) = 1.47,   S = 129.53
#  edges: 903,   elements: 9520,   edge complexity: 19.8 %,  elements complexity: 0.47 %
#
# iteration = 1100,   Score = 0.837
#
#  <E> = 127.14,  log(Z) = 1.76,   S = 128.9
#  edges: 919,   elements: 9763,   edge complexity: 20.15 %,  elements complexity: 0.49 %
#
# iteration = 1120,   Score = 0.839
#
#  <E> = 126.22,  log(Z) = 2.04,   S = 128.25
#  edges: 933,   elements: 10009,   edge complexity: 20.46 %,  elements complexity: 0.5 %
#
# iteration = 1140,   Score = 0.841
#
#  <E> = 125.17,  log(Z) = 2.28,   S = 127.45
#  edges: 947,   elements: 10248,   edge complexity: 20.77 %,  elements complexity: 0.51 %
#
# iteration = 1160,   Score = 0.841
#
#  <E> = 123.97,  log(Z) = 2.54,   S = 126.51
#  edges: 961,   elements: 10478,   edge complexity: 21.07 %,  elements complexity: 0.52 %
#
# iteration = 1180,   Score = 0.846
#
#  <E> = 123.63,  log(Z) = 2.76,   S = 126.39
#  edges: 976,   elements: 10683,   edge complexity: 21.4 %,  elements complexity: 0.53 %
#
# iteration = 1200,   Score = 0.845
#
#  <E> = 122.79,  log(Z) = 3.01,   S = 125.8
#  edges: 994,   elements: 10882,   edge complexity: 21.8 %,  elements complexity: 0.54 %
#
# iteration = 1220,   Score = 0.85
#
#  <E> = 121.92,  log(Z) = 3.23,   S = 125.15
#  edges: 1011,   elements: 11097,   edge complexity: 22.17 %,  elements complexity: 0.55 %
#
# iteration = 1240,   Score = 0.852
#
#  <E> = 121.44,  log(Z) = 3.53,   S = 124.97
#  edges: 1024,   elements: 11316,   edge complexity: 22.46 %,  elements complexity: 0.56 %
#
# iteration = 1260,   Score = 0.852
#
#  <E> = 120.9,  log(Z) = 3.78,   S = 124.68
#  edges: 1037,   elements: 11588,   edge complexity: 22.74 %,  elements complexity: 0.58 %
#
# iteration = 1280,   Score = 0.852
#
#  <E> = 119.78,  log(Z) = 3.96,   S = 123.75
#  edges: 1050,   elements: 11804,   edge complexity: 23.03 %,  elements complexity: 0.59 %
#
# iteration = 1300,   Score = 0.855
#
#  <E> = 118.86,  log(Z) = 4.15,   S = 123.0
#  edges: 1064,   elements: 12066,   edge complexity: 23.33 %,  elements complexity: 0.6 %
#
# iteration = 1320,   Score = 0.856
#
#  <E> = 118.27,  log(Z) = 4.36,   S = 122.62
#  edges: 1078,   elements: 12296,   edge complexity: 23.64 %,  elements complexity: 0.61 %
#
# iteration = 1340,   Score = 0.859
#
#  <E> = 118.17,  log(Z) = 4.49,   S = 122.66
#  edges: 1092,   elements: 12514,   edge complexity: 23.95 %,  elements complexity: 0.62 %
#
# iteration = 1360,   Score = 0.861
#
#  <E> = 117.34,  log(Z) = 4.8,   S = 122.14
#  edges: 1107,   elements: 12744,   edge complexity: 24.28 %,  elements complexity: 0.63 %
#
# iteration = 1380,   Score = 0.863
#
#  <E> = 117.29,  log(Z) = 5.01,   S = 122.3
#  edges: 1119,   elements: 12979,   edge complexity: 24.54 %,  elements complexity: 0.65 %
#
# iteration = 1400,   Score = 0.863
#
#  <E> = 116.45,  log(Z) = 5.25,   S = 121.7
#  edges: 1130,   elements: 13219,   edge complexity: 24.78 %,  elements complexity: 0.66 %
#
# iteration = 1420,   Score = 0.863
#
#  <E> = 115.71,  log(Z) = 5.47,   S = 121.18
#  edges: 1147,   elements: 13446,   edge complexity: 25.15 %,  elements complexity: 0.67 %
#
# iteration = 1440,   Score = 0.863
#
#  <E> = 115.66,  log(Z) = 5.73,   S = 121.39
#  edges: 1162,   elements: 13699,   edge complexity: 25.48 %,  elements complexity: 0.68 %
#
# iteration = 1460,   Score = 0.863
#
#  <E> = 114.34,  log(Z) = 5.98,   S = 120.32
#  edges: 1177,   elements: 13935,   edge complexity: 25.81 %,  elements complexity: 0.69 %
#
# iteration = 1480,   Score = 0.864
#
#  <E> = 114.44,  log(Z) = 6.25,   S = 120.68
#  edges: 1192,   elements: 14177,   edge complexity: 26.14 %,  elements complexity: 0.7 %
#
# iteration = 1500,   Score = 0.867
#
#  <E> = 113.36,  log(Z) = 6.47,   S = 119.83
#  edges: 1207,   elements: 14391,   edge complexity: 26.47 %,  elements complexity: 0.72 %
#
# iteration = 1520,   Score = 0.867
#
#  <E> = 113.07,  log(Z) = 6.68,   S = 119.74
#  edges: 1216,   elements: 14628,   edge complexity: 26.67 %,  elements complexity: 0.73 %
#
# iteration = 1540,   Score = 0.87
#
#  <E> = 112.25,  log(Z) = 6.94,   S = 119.19
#  edges: 1231,   elements: 14858,   edge complexity: 27.0 %,  elements complexity: 0.74 %
#
# iteration = 1560,   Score = 0.871
#
#  <E> = 111.29,  log(Z) = 7.24,   S = 118.53
#  edges: 1244,   elements: 15060,   edge complexity: 27.28 %,  elements complexity: 0.75 %
#
# iteration = 1580,   Score = 0.873
#
#  <E> = 109.27,  log(Z) = 7.51,   S = 116.78
#  edges: 1259,   elements: 15275,   edge complexity: 27.61 %,  elements complexity: 0.76 %
#
# iteration = 1600,   Score = 0.874
#
#  <E> = 108.92,  log(Z) = 7.68,   S = 116.6
#  edges: 1274,   elements: 15511,   edge complexity: 27.94 %,  elements complexity: 0.77 %
#
# iteration = 1620,   Score = 0.873
#
#  <E> = 108.9,  log(Z) = 7.84,   S = 116.74
#  edges: 1288,   elements: 15758,   edge complexity: 28.25 %,  elements complexity: 0.78 %
#
# iteration = 1640,   Score = 0.875
#
#  <E> = 108.47,  log(Z) = 8.08,   S = 116.56
#  edges: 1301,   elements: 15990,   edge complexity: 28.53 %,  elements complexity: 0.8 %
#
# iteration = 1660,   Score = 0.876
#
#  <E> = 107.54,  log(Z) = 8.31,   S = 115.86
#  edges: 1314,   elements: 16223,   edge complexity: 28.82 %,  elements complexity: 0.81 %
#
# iteration = 1680,   Score = 0.876
#
#  <E> = 107.77,  log(Z) = 8.52,   S = 116.29
#  edges: 1326,   elements: 16481,   edge complexity: 29.08 %,  elements complexity: 0.82 %
#
# iteration = 1700,   Score = 0.878
#
#  <E> = 106.98,  log(Z) = 8.7,   S = 115.68
#  edges: 1340,   elements: 16716,   edge complexity: 29.39 %,  elements complexity: 0.83 %
#
# iteration = 1720,   Score = 0.879
#
#  <E> = 106.04,  log(Z) = 8.86,   S = 114.9
#  edges: 1354,   elements: 16930,   edge complexity: 29.69 %,  elements complexity: 0.84 %
#
# iteration = 1740,   Score = 0.881
#
#  <E> = 104.8,  log(Z) = 9.08,   S = 113.87
#  edges: 1367,   elements: 17170,   edge complexity: 29.98 %,  elements complexity: 0.85 %
#
# iteration = 1760,   Score = 0.882
#
#  <E> = 104.05,  log(Z) = 9.28,   S = 113.33
#  edges: 1382,   elements: 17398,   edge complexity: 30.31 %,  elements complexity: 0.87 %
#
# iteration = 1780,   Score = 0.883
#
#  <E> = 103.91,  log(Z) = 9.42,   S = 113.33
#  edges: 1393,   elements: 17643,   edge complexity: 30.55 %,  elements complexity: 0.88 %
#
# iteration = 1800,   Score = 0.884
#
#  <E> = 103.64,  log(Z) = 9.61,   S = 113.25
#  edges: 1404,   elements: 17912,   edge complexity: 30.79 %,  elements complexity: 0.89 %
#
# iteration = 1820,   Score = 0.884
#
#  <E> = 103.36,  log(Z) = 9.83,   S = 113.19
#  edges: 1414,   elements: 18159,   edge complexity: 31.01 %,  elements complexity: 0.9 %
#
# iteration = 1840,   Score = 0.885
#
#  <E> = 102.77,  log(Z) = 10.02,   S = 112.79
#  edges: 1422,   elements: 18399,   edge complexity: 31.18 %,  elements complexity: 0.91 %
#
# iteration = 1860,   Score = 0.886
#
#  <E> = 102.33,  log(Z) = 10.25,   S = 112.58
#  edges: 1432,   elements: 18621,   edge complexity: 31.4 %,  elements complexity: 0.93 %
#
# iteration = 1880,   Score = 0.888
#
#  <E> = 101.43,  log(Z) = 10.45,   S = 111.88
#  edges: 1448,   elements: 18846,   edge complexity: 31.75 %,  elements complexity: 0.94 %
#
# iteration = 1900,   Score = 0.888
#
#  <E> = 101.14,  log(Z) = 10.67,   S = 111.81
#  edges: 1461,   elements: 19084,   edge complexity: 32.04 %,  elements complexity: 0.95 %
#
# iteration = 1920,   Score = 0.889
#
#  <E> = 100.47,  log(Z) = 10.91,   S = 111.38
#  edges: 1474,   elements: 19325,   edge complexity: 32.32 %,  elements complexity: 0.96 %
#
# iteration = 1940,   Score = 0.888
#
#  <E> = 99.72,  log(Z) = 11.1,   S = 110.82
#  edges: 1487,   elements: 19589,   edge complexity: 32.61 %,  elements complexity: 0.97 %
#
# iteration = 1960,   Score = 0.89
#
#  <E> = 99.55,  log(Z) = 11.33,   S = 110.87
#  edges: 1499,   elements: 19828,   edge complexity: 32.87 %,  elements complexity: 0.99 %
#
# iteration = 1980,   Score = 0.89
#
#  <E> = 98.87,  log(Z) = 11.58,   S = 110.45
#  edges: 1510,   elements: 20072,   edge complexity: 33.11 %,  elements complexity: 1.0 %
#
# iteration = 2000,   Score = 0.892
#
#  <E> = 98.75,  log(Z) = 11.87,   S = 110.62
#  edges: 1520,   elements: 20310,   edge complexity: 33.33 %,  elements complexity: 1.01 %
#
# iteration = 2020,   Score = 0.892
#
#  <E> = 97.56,  log(Z) = 12.08,   S = 109.64
#  edges: 1530,   elements: 20578,   edge complexity: 33.55 %,  elements complexity: 1.02 %
#
# iteration = 2040,   Score = 0.892
#
#  <E> = 97.15,  log(Z) = 12.33,   S = 109.48
#  edges: 1543,   elements: 20808,   edge complexity: 33.84 %,  elements complexity: 1.03 %
#
# iteration = 2060,   Score = 0.893
#
#  <E> = 97.27,  log(Z) = 12.54,   S = 109.81
#  edges: 1554,   elements: 21073,   edge complexity: 34.08 %,  elements complexity: 1.05 %
#
# iteration = 2080,   Score = 0.893
#
#  <E> = 96.33,  log(Z) = 12.79,   S = 109.12
#  edges: 1570,   elements: 21306,   edge complexity: 34.43 %,  elements complexity: 1.06 %
#
# iteration = 2100,   Score = 0.895
#
#  <E> = 96.56,  log(Z) = 13.0,   S = 109.57
#  edges: 1583,   elements: 21554,   edge complexity: 34.71 %,  elements complexity: 1.07 %
#
# iteration = 2120,   Score = 0.894
#
#  <E> = 95.85,  log(Z) = 13.24,   S = 109.09
#  edges: 1597,   elements: 21815,   edge complexity: 35.02 %,  elements complexity: 1.08 %
#
# iteration = 2140,   Score = 0.895
#
#  <E> = 94.69,  log(Z) = 13.5,   S = 108.19
#  edges: 1609,   elements: 22075,   edge complexity: 35.29 %,  elements complexity: 1.1 %
#
# iteration = 2160,   Score = 0.896
#
#  <E> = 94.55,  log(Z) = 13.75,   S = 108.3
#  edges: 1623,   elements: 22328,   edge complexity: 35.59 %,  elements complexity: 1.11 %
#
# iteration = 2180,   Score = 0.897
#
#  <E> = 93.21,  log(Z) = 14.0,   S = 107.21
#  edges: 1635,   elements: 22569,   edge complexity: 35.86 %,  elements complexity: 1.12 %
#
# iteration = 2200,   Score = 0.898
#
#  <E> = 93.24,  log(Z) = 14.25,   S = 107.49
#  edges: 1642,   elements: 22828,   edge complexity: 36.01 %,  elements complexity: 1.14 %
#
# iteration = 2220,   Score = 0.898
#
#  <E> = 93.3,  log(Z) = 14.46,   S = 107.76
#  edges: 1656,   elements: 23059,   edge complexity: 36.32 %,  elements complexity: 1.15 %
#
# iteration = 2240,   Score = 0.898
#
#  <E> = 92.59,  log(Z) = 14.76,   S = 107.35
#  edges: 1668,   elements: 23305,   edge complexity: 36.58 %,  elements complexity: 1.16 %
#
# iteration = 2260,   Score = 0.899
#
#  <E> = 91.54,  log(Z) = 15.02,   S = 106.56
#  edges: 1681,   elements: 23547,   edge complexity: 36.86 %,  elements complexity: 1.17 %
#
# iteration = 2280,   Score = 0.9
#
#  <E> = 91.21,  log(Z) = 15.27,   S = 106.48
#
# The selceted model has 1689 edges and a score = 0.9
# 49821.81230592728

# %% [markdown]
# ## saving data

# %%
using JLD

init_pseudo_count = 0.01
folder_name = "../training/" * method * string(fraction) * "_stop=" * string(stop) * "_reg="*string(pseudo_count)*"_h_ps-count=" * string(init_pseudo_count) * "nbook="*notebook

JLD.save(folder_name*"/"*"score.jld","data", score)
JLD.save(folder_name*"/"*"likelihood_gain.jld","data", likelihood_gain)
JLD.save(folder_name*"/"*"generated_sequences.jld","data", generated_sequences)
JLD.save(folder_name*"/"*"Jij.jld","data", Jij)
JLD.save(folder_name*"/"*"h.jld","data", h)
JLD.save(folder_name*"/"*"contact_list.jld","data", contact_list)
JLD.save(folder_name*"/"*"site_degree.jld","data", site_degree)
JLD.save(folder_name*"/"*"edge_list.jld","data", edge_list)

# %% [markdown]
# ## Saving the model

# %%
function print_model_to_file_prot(natural_sequences,Jij,h,filename)
    open(filename, "w") do f
        for i in 1:length(natural_sequences[1,:])
            for j in i+1:length(natural_sequences[1,:])
                for k in 1:21    
                    if k==1
                        k2=1        
                    elseif k==2
                        k2=2
                    elseif k==3
                        k2=3
                    elseif k==4
                        k2=4
                    elseif k==5
                        k2=5
                    elseif k==6
                        k2=6
                    elseif k==7
                        k2=7
                    elseif k==8
                        k2=8
                    elseif k==9
                        k2=9
                    elseif k==10
                        k2=10
                    elseif k==11
                        k2=11
                    elseif k==12
                        k2=12
                    elseif k==13
                        k2=13
                    elseif k==14
                        k2=14
                    elseif k==15
                        k2=15
                    elseif k==16
                        k2=16
                    elseif k==17
                        k2=17
                    elseif k==18
                        k2=18
                    elseif k==19
                        k2=19
                    elseif k==20
                        k2=20
                    elseif k==21
                        k2=0
                    end
                        
                    for l in 1:21
                        if l==1
                            l2=1
                        elseif l==2
                            l2=2
                        elseif l==3
                            l2=3
                        elseif l==4
                            l2=4
                        elseif l==5
                            l2=5
                        elseif l==6
                            l2=6
                        elseif l==7
                            l2=7
                        elseif l==8
                            l2=8
                        elseif l==9
                            l2=9
                        elseif l==10
                            l2=10
                        elseif l==11
                            l2=11
                        elseif l==12
                            l2=12
                        elseif l==13
                            l2=13
                        elseif l==14
                            l2=14
                        elseif l==15
                            l2=15
                        elseif l==16
                            l2=16
                        elseif l==17
                            l2=17
                        elseif l==18
                            l2=18
                        elseif l==19
                            l2=19
                        elseif l==20
                            l2=20
                        elseif l==21
                            l2=0
                        end
                        opo=Jij[i,j,21*(k-1)+l]
                        write(f,"\nJ $(i-1) $(j-1) $(k2) $(l2) $opo" )
                    end
                end
            end
        end
        for i in 1:length(natural_sequences[1,:])
            for j in 1:21          
                if j==1
                    j2=1
                elseif j==2
                    j2=2
                elseif j==3
                    j2=3
                elseif j==4
                    j2=4
                elseif j==5
                    j2=5
                elseif j==6
                    j2=6
                elseif j==7
                    j2=7
                elseif j==8
                    j2=8
                elseif j==9
                    j2=9
                elseif j==10
                    j2=10
                elseif j==11
                    j2=11
                elseif j==12
                    j2=12
                elseif j==13
                    j2=13
                elseif j==14
                    j2=14
                elseif j==15
                    j2=15
                elseif j==16
                    j2=16
                elseif j==17
                    j2=17
                elseif j==18
                    j2=18
                elseif j==19
                    j2=19
                elseif j==20
                    j2=20
                elseif j==21
                    j2=0
                end
                opo=h[21*(i-1)+j]
                write(f,"\nh $(i-1) $(j2) $opo" )
            end
        end
    end
end
# Out:
# print_model_to_file_prot (generic function with 1 method)

# %%
filename = "../saved_models/model_cumulative0.3_pseudocount0.5_init_pscount0.01_nbook_test1.txt"
print_model_to_file_prot(natural_sequences, Jij, h, filename)

# %% [markdown]
# <font size="3">The model obtained has a performance comparable to the fully connected DCA while having just ~20% of its connectivity. The entropy of the model is 35.08. This means that it is able to generate e³⁵ (3.5x10¹⁵) different 55-102 segments for the RF00379 family. \
# Now we can test our artificial sequences. We do the classical statistical check of the PCA projection and the two-point correlation representation. \
# We test the performance of our model against the one of the Covariance Model. The CM model only contains trivial one-point and secondary information so our model must do better than it. </font>

# %%
cm_sequences = rna_cm_model_generation(0.8,0.05,7000,natural_sequences,ss_contact_matrix);

# %%
plot_stat_check(natural_sequences, generated_sequences, cm_sequences)

# %% [markdown]
# <font size="3">The E.A.A. artificial molecules are practically statistically indistinguishable from the natural ones. We see that they have a very similar PCA projection (artificial one seems richer just because we have more artificial sequences than natural ones) while Covariance Model fails to capture the details of the distribution.
#     The selected model has almost a perfect two-point statistics for all site pairs while the CM model only captures it for the ones involved in secondary structure contacts. \
#      </font>

# %% [markdown]
# <font size="3">The interpretability is one of the main reasons in our quest to find parsimonious generative models. Now that we are sure we obtained a good generative model with relatively few parameters we can try to interprete them. \
# Dividing the added edges in secondary structure contacts, 3D contacts we have:

# %%
edge_interpretation_plot(len,ss_contact_matrix,tertiary_contact_matrix,edge_list[1:50,:])

# %% [markdown]
# <font size="3">We see that the secondary structure contacts are taken in the first few iteration. We have lot of neighbouring sites probably due to philogenic effects. It is striking that we see some 3D contacts (in particular around site 40) before the NONE edges. This
# suggests that our algorithm effectively captures some information about the tertiary structure. \
# Those results, that are far more general than this simple example, suggest that the added edges have a co-evolutionary interpretation.

# %% [markdown]
# <font size="3">
# This notebook serves as an example of the application of the techniques described in the main text.
